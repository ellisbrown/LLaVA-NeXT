# %%
import os
from tqdm import tqdm
import json
import pandas as pd
import io
import yaml

# %%
def clean_subset_name(name):
    """Clean subset name for use as directory name."""
    return ''.join(c if c.isalnum() else '_' for c in name).strip('_')


json_paths = [
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_metagen_87358.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_rule_geo_100000.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/k12_printing_train_256646.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/iiit5k_annotations_2000.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/hme100k_train_clean_74502.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_azuregpt_detailed_understanding_4874.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_vqa_4404.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_azuregpt4v_1992.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_chart_1787.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_normal_gpt4v_filtered_10500.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/scienceqa_nona_context_19218.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_vflan4v_20000.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_laion4v_50000.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textocr_gpt4v_train_converted_25114.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_train_internvl_single_12413.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textcaps_train_21952.json",
    "/mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_qa_sft.json",
    "/mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_cap_sft.json",
    "/mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_ie_sft.json",
    "/mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_kg_sft.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/vision_flan_filtered_186070.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mathqa_29837.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo3k_2101.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_qa_converted_67833.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_align_converted_60252.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-coco-50k.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-knowledge-2k.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-llava-30k.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-sam-20k.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_CLEVR-Math_5290.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_FigureQA_17597.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Geometry3K_9734.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GeoQA+_17172.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GEOS_508.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_IconQA_22599.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_MapQA_5235.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PMC-VQA_35958.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Super-CLEVR_8652.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TabMWP_22462.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_UniGeo_11959.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VizWiz_6614.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_qwen2_72b_st_300000_sp_token_fltd_299992.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_st_300000.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_mt_300000_sp_token_fltd_299998.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/image_textualization_dataset_filtered.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/cambrian_filtered_gpt4vo_sp_token_fltd_max10k.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4o_dataset.jsonl",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/ai2d_llava_format_2434.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/aokvqa_16539_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/chart2text_26961.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/chartqa_18265_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/clevr_70000_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/diagram_image_to_text_300.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/dvqa_200000_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/figureqa_100000_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/geomverse_9303.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/hateful_memes_8500_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/hitab_2500_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/iam_5663.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/raven_42000.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/iconqa_llava_format_27307.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/infographic_vqa_2118_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/intergps_1280_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/mapqa_37417_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/multihiertt_7619.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/rendered_text_10000.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/robut_sqa_8514.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wikisql_74989.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wtq_38246_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/screen2words_15730.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/scienceqa_llava_format_4976.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/tabmwp_22722.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/tallyqa_98680_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/st_vqa_17247_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/tqa_llava_format_27307.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/visual7w_llava_format_14366.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/visualmrc_3027.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/vqarad_313_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/vsr_2157_llava_format.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/vistext_9969.json",
    "/mnt/bn/vl-research/data/llava_instruct/cauldron/websight_10000.json"
]

short_names = [
    "mavis_math_metagen",
    "mavis_math_rule_geo",
    "k12_printing",
    "iiit5k",
    "hme100k",
    "ai2d(gpt4v)",
    "infographic_vqa",
    "infographic(gpt4v)",
    "lrv_chart",
    "lrv_normal(filtered)",
    "scienceqa(nona_context)",
    "allava_instruct_vflan4v",
    "allava_instruct_laion4v",
    "textocr(gpt4v)",
    "ai2d(internvl)",
    "textcaps",
    "ureader_qa", # need to re-upload
    "ureader_cap", # need to re-upload
    "ureader_ie", # need to re-upload
    "ureader_kg", # need to re-upload
    "vision_flan(filtered)",
    "mathqa",
    "geo3k",
    "geo170k(qa)",
    "geo170k(align)",
    "sharegpt4v(coco)",
    "sharegpt4v(knowledge)",
    "sharegpt4v(llava)",
    "sharegpt4v(sam)",
    "CLEVR-Math(MathV360K)",
    "FigureQA(MathV360K)",
    "Geometry3K(MathV360K)",
    "GeoQA+(MathV360K)",
    "GEOS(MathV360K)",
    "IconQA(MathV360K)",
    "MapQA(MathV360K)",
    "PMC-VQA(MathV360K)",
    "Super-CLEVR(MathV360K)",
    "TabMWP(MathV360K)",
    "UniGeo(MathV360K)",
    "VizWiz(MathV360K)",
    "magpie_pro(qwen2_72b_st)",
    "magpie_pro(l3_80b_st)",
    "magpie_pro(l3_80b_mt)",
    "image_textualization(filtered)",
    "cambrian(filtered_gpt4vo)", # need to re-upload
    "sharegpt4o",
    "ai2d(cauldron,llava_format)",
    "aokvqa(cauldron,llava_format)",
    "chart2text(cauldron)",
    "chartqa(cauldron,llava_format)",
    "clevr(cauldron,llava_format)",
    "diagram_image_to_text(cauldron)",
    "dvqa(cauldron,llava_format)",
    "figureqa(cauldron,llava_format)",
    "geomverse(cauldron)",
    "hateful_memes(cauldron,llava_format)",
    "hitab(cauldron,llava_format)",
    "iam(cauldron)",
    "raven(cauldron)",
    "iconqa(cauldron,llava_format)",
    "infographic_vqa_llava_format",
    "intergps(cauldron,llava_format)",
    "mapqa(cauldron,llava_format)",
    "multihiertt(cauldron)",
    "rendered_text(cauldron)",
    "robut_sqa(cauldron)",
    "robut_wikisql(cauldron)",
    "robut_wtq(cauldron,llava_format)",
    "screen2words(cauldron)",
    "scienceqa(cauldron,llava_format)",
    "tabmwp(cauldron)",
    "tallyqa(cauldron,llava_format)",
    "st_vqa(cauldron,llava_format)",
    "tqa(cauldron,llava_format)",
    "visual7w(cauldron,llava_format)",
    "visualmrc(cauldron)",
    "vqarad(cauldron,llava_format)",
    "vsr(cauldron,llava_format)",
    "vistext(cauldron)",
    "websight(cauldron)"
]
df = pd.DataFrame({"json_path": json_paths, "short_names": short_names})
df["clean_names"] = df["short_names"].apply(clean_subset_name)
df
# Out:
#                                                                                                             json_path  \
# 0                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_metagen_87358.json
# 1                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_rule_geo_100000.json
# 2                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/k12_printing_train_256646.json
# 3                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/iiit5k_annotations_2000.json
# 4                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/hme100k_train_clean_74502.json
# 5             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_azuregpt_detailed_understanding_4874.json
# 6                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_vqa_4404.json
# 7                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_azuregpt4v_1992.json
# 8                                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_chart_1787.json
# 9                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_normal_gpt4v_filtered_10500.json
# 10                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/scienceqa_nona_context_19218.json
# 11                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_vflan4v_20000.json
# 12                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_laion4v_50000.json
# 13                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textocr_gpt4v_train_converted_25114.json
# 14                     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_train_internvl_single_12413.json
# 15                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textcaps_train_21952.json
# 16                                            /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_qa_sft.json
# 17                                           /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_cap_sft.json
# 18                                            /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_ie_sft.json
# 19                                            /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_kg_sft.json
# 20                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/vision_flan_filtered_186070.json
# 21                                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mathqa_29837.json
# 22                                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo3k_2101.json
# 23                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_qa_converted_67833.json
# 24                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_align_converted_60252.json
# 25                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-coco-50k.json
# 26                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-knowledge-2k.json
# 27                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-llava-30k.json
# 28                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-sam-20k.json
# 29                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_CLEVR-Math_5290.json
# 30                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_FigureQA_17597.json
# 31                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Geometry3K_9734.json
# 32                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GeoQA+_17172.json
# 33                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GEOS_508.json
# 34                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_IconQA_22599.json
# 35                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_MapQA_5235.json
# 36                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PMC-VQA_35958.json
# 37                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Super-CLEVR_8652.json
# 38                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TabMWP_22462.json
# 39                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_UniGeo_11959.json
# 40                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VizWiz_6614.json
# 41  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_qwen2_72b_st_300000_sp_token_fltd_299992.json
# 42                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_st_300000.json
# 43     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_mt_300000_sp_token_fltd_299998.json
# 44                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/image_textualization_dataset_filtered.json
# 45        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/cambrian_filtered_gpt4vo_sp_token_fltd_max10k.json
# 46                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4o_dataset.jsonl
# 47                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/ai2d_llava_format_2434.json
# 48                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/aokvqa_16539_llava_format.json
# 49                                             /mnt/bn/vl-research/data/llava_instruct/cauldron/chart2text_26961.json
# 50                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/chartqa_18265_llava_format.json
# 51                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/clevr_70000_llava_format.json
# 52                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/diagram_image_to_text_300.json
# 53                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/dvqa_200000_llava_format.json
# 54                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/figureqa_100000_llava_format.json
# 55                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/geomverse_9303.json
# 56                              /mnt/bn/vl-research/data/llava_instruct/cauldron/hateful_memes_8500_llava_format.json
# 57                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/hitab_2500_llava_format.json
# 58                                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/iam_5663.json
# 59                                                  /mnt/bn/vl-research/data/llava_instruct/cauldron/raven_42000.json
# 60                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/iconqa_llava_format_27307.json
# 61                            /mnt/bn/vl-research/data/llava_instruct/cauldron/infographic_vqa_2118_llava_format.json
# 62                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/intergps_1280_llava_format.json
# 63                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/mapqa_37417_llava_format.json
# 64                                             /mnt/bn/vl-research/data/llava_instruct/cauldron/multihiertt_7619.json
# 65                                          /mnt/bn/vl-research/data/llava_instruct/cauldron/rendered_text_10000.json
# 66                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_sqa_8514.json
# 67                                          /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wikisql_74989.json
# 68                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wtq_38246_llava_format.json
# 69                                           /mnt/bn/vl-research/data/llava_instruct/cauldron/screen2words_15730.json
# 70                                  /mnt/bn/vl-research/data/llava_instruct/cauldron/scienceqa_llava_format_4976.json
# 71                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/tabmwp_22722.json
# 72                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/tallyqa_98680_llava_format.json
# 73                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/st_vqa_17247_llava_format.json
# 74                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/tqa_llava_format_27307.json
# 75                                  /mnt/bn/vl-research/data/llava_instruct/cauldron/visual7w_llava_format_14366.json
# 76                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/visualmrc_3027.json
# 77                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/vqarad_313_llava_format.json
# 78                                        /mnt/bn/vl-research/data/llava_instruct/cauldron/vsr_2157_llava_format.json
# 79                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/vistext_9969.json
# 80                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/websight_10000.json
#
#                              short_names                          clean_names
# 0                     mavis_math_metagen                   mavis_math_metagen
# 1                    mavis_math_rule_geo                  mavis_math_rule_geo
# 2                           k12_printing                         k12_printing
# 3                                 iiit5k                               iiit5k
# 4                                hme100k                              hme100k
# 5                            ai2d(gpt4v)                           ai2d_gpt4v
# 6                        infographic_vqa                      infographic_vqa
# 7                     infographic(gpt4v)                    infographic_gpt4v
# 8                              lrv_chart                            lrv_chart
# 9                   lrv_normal(filtered)                  lrv_normal_filtered
# 10               scienceqa(nona_context)               scienceqa_nona_context
# 11               allava_instruct_vflan4v              allava_instruct_vflan4v
# 12               allava_instruct_laion4v              allava_instruct_laion4v
# 13                        textocr(gpt4v)                        textocr_gpt4v
# 14                        ai2d(internvl)                        ai2d_internvl
# 15                              textcaps                             textcaps
# 16                            ureader_qa                           ureader_qa
# 17                           ureader_cap                          ureader_cap
# 18                            ureader_ie                           ureader_ie
# 19                            ureader_kg                           ureader_kg
# 20                 vision_flan(filtered)                 vision_flan_filtered
# 21                                mathqa                               mathqa
# 22                                 geo3k                                geo3k
# 23                           geo170k(qa)                           geo170k_qa
# 24                        geo170k(align)                        geo170k_align
# 25                      sharegpt4v(coco)                      sharegpt4v_coco
# 26                 sharegpt4v(knowledge)                 sharegpt4v_knowledge
# 27                     sharegpt4v(llava)                     sharegpt4v_llava
# 28                       sharegpt4v(sam)                       sharegpt4v_sam
# 29                 CLEVR-Math(MathV360K)                 CLEVR_Math_MathV360K
# 30                   FigureQA(MathV360K)                   FigureQA_MathV360K
# 31                 Geometry3K(MathV360K)                 Geometry3K_MathV360K
# 32                     GeoQA+(MathV360K)                     GeoQA__MathV360K
# 33                       GEOS(MathV360K)                       GEOS_MathV360K
# 34                     IconQA(MathV360K)                     IconQA_MathV360K
# 35                      MapQA(MathV360K)                      MapQA_MathV360K
# 36                    PMC-VQA(MathV360K)                    PMC_VQA_MathV360K
# 37                Super-CLEVR(MathV360K)                Super_CLEVR_MathV360K
# 38                     TabMWP(MathV360K)                     TabMWP_MathV360K
# 39                     UniGeo(MathV360K)                     UniGeo_MathV360K
# 40                     VizWiz(MathV360K)                     VizWiz_MathV360K
# 41              magpie_pro(qwen2_72b_st)              magpie_pro_qwen2_72b_st
# 42                 magpie_pro(l3_80b_st)                 magpie_pro_l3_80b_st
# 43                 magpie_pro(l3_80b_mt)                 magpie_pro_l3_80b_mt
# 44        image_textualization(filtered)        image_textualization_filtered
# 45             cambrian(filtered_gpt4vo)             cambrian_filtered_gpt4vo
# 46                            sharegpt4o                           sharegpt4o
# 47           ai2d(cauldron,llava_format)           ai2d_cauldron_llava_format
# 48         aokvqa(cauldron,llava_format)         aokvqa_cauldron_llava_format
# 49                  chart2text(cauldron)                  chart2text_cauldron
# 50        chartqa(cauldron,llava_format)        chartqa_cauldron_llava_format
# 51          clevr(cauldron,llava_format)          clevr_cauldron_llava_format
# 52       diagram_image_to_text(cauldron)       diagram_image_to_text_cauldron
# 53           dvqa(cauldron,llava_format)           dvqa_cauldron_llava_format
# 54       figureqa(cauldron,llava_format)       figureqa_cauldron_llava_format
# 55                   geomverse(cauldron)                   geomverse_cauldron
# 56  hateful_memes(cauldron,llava_format)  hateful_memes_cauldron_llava_format
# 57          hitab(cauldron,llava_format)          hitab_cauldron_llava_format
# 58                         iam(cauldron)                         iam_cauldron
# 59                       raven(cauldron)                       raven_cauldron
# 60         iconqa(cauldron,llava_format)         iconqa_cauldron_llava_format
# 61          infographic_vqa_llava_format         infographic_vqa_llava_format
# 62       intergps(cauldron,llava_format)       intergps_cauldron_llava_format
# 63          mapqa(cauldron,llava_format)          mapqa_cauldron_llava_format
# 64                 multihiertt(cauldron)                 multihiertt_cauldron
# 65               rendered_text(cauldron)               rendered_text_cauldron
# 66                   robut_sqa(cauldron)                   robut_sqa_cauldron
# 67               robut_wikisql(cauldron)               robut_wikisql_cauldron
# 68      robut_wtq(cauldron,llava_format)      robut_wtq_cauldron_llava_format
# 69                screen2words(cauldron)                screen2words_cauldron
# 70      scienceqa(cauldron,llava_format)      scienceqa_cauldron_llava_format
# 71                      tabmwp(cauldron)                      tabmwp_cauldron
# 72        tallyqa(cauldron,llava_format)        tallyqa_cauldron_llava_format
# 73         st_vqa(cauldron,llava_format)         st_vqa_cauldron_llava_format
# 74            tqa(cauldron,llava_format)            tqa_cauldron_llava_format
# 75       visual7w(cauldron,llava_format)       visual7w_cauldron_llava_format
# 76                   visualmrc(cauldron)                   visualmrc_cauldron
# 77         vqarad(cauldron,llava_format)         vqarad_cauldron_llava_format
# 78            vsr(cauldron,llava_format)            vsr_cauldron_llava_format
# 79                     vistext(cauldron)                     vistext_cauldron
# 80                    websight(cauldron)                    websight_cauldron

# %%
img_path = "/data/weka/ellisb/datasets/video/llava_ov_data/images"

df["img_dir"] = df["clean_names"].apply(lambda x: os.path.join(img_path, x))
df["exists"] = df["img_dir"].apply(os.path.exists)
df
# Out:
#                                                                                                             json_path  \
# 0                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_metagen_87358.json
# 1                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_rule_geo_100000.json
# 2                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/k12_printing_train_256646.json
# 3                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/iiit5k_annotations_2000.json
# 4                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/hme100k_train_clean_74502.json
# 5             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_azuregpt_detailed_understanding_4874.json
# 6                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_vqa_4404.json
# 7                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_azuregpt4v_1992.json
# 8                                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_chart_1787.json
# 9                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_normal_gpt4v_filtered_10500.json
# 10                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/scienceqa_nona_context_19218.json
# 11                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_vflan4v_20000.json
# 12                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_laion4v_50000.json
# 13                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textocr_gpt4v_train_converted_25114.json
# 14                     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_train_internvl_single_12413.json
# 15                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textcaps_train_21952.json
# 16                                            /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_qa_sft.json
# 17                                           /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_cap_sft.json
# 18                                            /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_ie_sft.json
# 19                                            /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_kg_sft.json
# 20                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/vision_flan_filtered_186070.json
# 21                                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mathqa_29837.json
# 22                                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo3k_2101.json
# 23                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_qa_converted_67833.json
# 24                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_align_converted_60252.json
# 25                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-coco-50k.json
# 26                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-knowledge-2k.json
# 27                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-llava-30k.json
# 28                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-sam-20k.json
# 29                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_CLEVR-Math_5290.json
# 30                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_FigureQA_17597.json
# 31                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Geometry3K_9734.json
# 32                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GeoQA+_17172.json
# 33                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GEOS_508.json
# 34                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_IconQA_22599.json
# 35                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_MapQA_5235.json
# 36                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PMC-VQA_35958.json
# 37                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Super-CLEVR_8652.json
# 38                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TabMWP_22462.json
# 39                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_UniGeo_11959.json
# 40                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VizWiz_6614.json
# 41  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_qwen2_72b_st_300000_sp_token_fltd_299992.json
# 42                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_st_300000.json
# 43     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_mt_300000_sp_token_fltd_299998.json
# 44                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/image_textualization_dataset_filtered.json
# 45        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/cambrian_filtered_gpt4vo_sp_token_fltd_max10k.json
# 46                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4o_dataset.jsonl
# 47                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/ai2d_llava_format_2434.json
# 48                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/aokvqa_16539_llava_format.json
# 49                                             /mnt/bn/vl-research/data/llava_instruct/cauldron/chart2text_26961.json
# 50                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/chartqa_18265_llava_format.json
# 51                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/clevr_70000_llava_format.json
# 52                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/diagram_image_to_text_300.json
# 53                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/dvqa_200000_llava_format.json
# 54                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/figureqa_100000_llava_format.json
# 55                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/geomverse_9303.json
# 56                              /mnt/bn/vl-research/data/llava_instruct/cauldron/hateful_memes_8500_llava_format.json
# 57                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/hitab_2500_llava_format.json
# 58                                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/iam_5663.json
# 59                                                  /mnt/bn/vl-research/data/llava_instruct/cauldron/raven_42000.json
# 60                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/iconqa_llava_format_27307.json
# 61                            /mnt/bn/vl-research/data/llava_instruct/cauldron/infographic_vqa_2118_llava_format.json
# 62                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/intergps_1280_llava_format.json
# 63                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/mapqa_37417_llava_format.json
# 64                                             /mnt/bn/vl-research/data/llava_instruct/cauldron/multihiertt_7619.json
# 65                                          /mnt/bn/vl-research/data/llava_instruct/cauldron/rendered_text_10000.json
# 66                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_sqa_8514.json
# 67                                          /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wikisql_74989.json
# 68                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wtq_38246_llava_format.json
# 69                                           /mnt/bn/vl-research/data/llava_instruct/cauldron/screen2words_15730.json
# 70                                  /mnt/bn/vl-research/data/llava_instruct/cauldron/scienceqa_llava_format_4976.json
# 71                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/tabmwp_22722.json
# 72                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/tallyqa_98680_llava_format.json
# 73                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/st_vqa_17247_llava_format.json
# 74                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/tqa_llava_format_27307.json
# 75                                  /mnt/bn/vl-research/data/llava_instruct/cauldron/visual7w_llava_format_14366.json
# 76                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/visualmrc_3027.json
# 77                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/vqarad_313_llava_format.json
# 78                                        /mnt/bn/vl-research/data/llava_instruct/cauldron/vsr_2157_llava_format.json
# 79                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/vistext_9969.json
# 80                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/websight_10000.json
#
#                              short_names                          clean_names  \
# 0                     mavis_math_metagen                   mavis_math_metagen
# 1                    mavis_math_rule_geo                  mavis_math_rule_geo
# 2                           k12_printing                         k12_printing
# 3                                 iiit5k                               iiit5k
# 4                                hme100k                              hme100k
# 5                            ai2d(gpt4v)                           ai2d_gpt4v
# 6                        infographic_vqa                      infographic_vqa
# 7                     infographic(gpt4v)                    infographic_gpt4v
# 8                              lrv_chart                            lrv_chart
# 9                   lrv_normal(filtered)                  lrv_normal_filtered
# 10               scienceqa(nona_context)               scienceqa_nona_context
# 11               allava_instruct_vflan4v              allava_instruct_vflan4v
# 12               allava_instruct_laion4v              allava_instruct_laion4v
# 13                        textocr(gpt4v)                        textocr_gpt4v
# 14                        ai2d(internvl)                        ai2d_internvl
# 15                              textcaps                             textcaps
# 16                            ureader_qa                           ureader_qa
# 17                           ureader_cap                          ureader_cap
# 18                            ureader_ie                           ureader_ie
# 19                            ureader_kg                           ureader_kg
# 20                 vision_flan(filtered)                 vision_flan_filtered
# 21                                mathqa                               mathqa
# 22                                 geo3k                                geo3k
# 23                           geo170k(qa)                           geo170k_qa
# 24                        geo170k(align)                        geo170k_align
# 25                      sharegpt4v(coco)                      sharegpt4v_coco
# 26                 sharegpt4v(knowledge)                 sharegpt4v_knowledge
# 27                     sharegpt4v(llava)                     sharegpt4v_llava
# 28                       sharegpt4v(sam)                       sharegpt4v_sam
# 29                 CLEVR-Math(MathV360K)                 CLEVR_Math_MathV360K
# 30                   FigureQA(MathV360K)                   FigureQA_MathV360K
# 31                 Geometry3K(MathV360K)                 Geometry3K_MathV360K
# 32                     GeoQA+(MathV360K)                     GeoQA__MathV360K
# 33                       GEOS(MathV360K)                       GEOS_MathV360K
# 34                     IconQA(MathV360K)                     IconQA_MathV360K
# 35                      MapQA(MathV360K)                      MapQA_MathV360K
# 36                    PMC-VQA(MathV360K)                    PMC_VQA_MathV360K
# 37                Super-CLEVR(MathV360K)                Super_CLEVR_MathV360K
# 38                     TabMWP(MathV360K)                     TabMWP_MathV360K
# 39                     UniGeo(MathV360K)                     UniGeo_MathV360K
# 40                     VizWiz(MathV360K)                     VizWiz_MathV360K
# 41              magpie_pro(qwen2_72b_st)              magpie_pro_qwen2_72b_st
# 42                 magpie_pro(l3_80b_st)                 magpie_pro_l3_80b_st
# 43                 magpie_pro(l3_80b_mt)                 magpie_pro_l3_80b_mt
# 44        image_textualization(filtered)        image_textualization_filtered
# 45             cambrian(filtered_gpt4vo)             cambrian_filtered_gpt4vo
# 46                            sharegpt4o                           sharegpt4o
# 47           ai2d(cauldron,llava_format)           ai2d_cauldron_llava_format
# 48         aokvqa(cauldron,llava_format)         aokvqa_cauldron_llava_format
# 49                  chart2text(cauldron)                  chart2text_cauldron
# 50        chartqa(cauldron,llava_format)        chartqa_cauldron_llava_format
# 51          clevr(cauldron,llava_format)          clevr_cauldron_llava_format
# 52       diagram_image_to_text(cauldron)       diagram_image_to_text_cauldron
# 53           dvqa(cauldron,llava_format)           dvqa_cauldron_llava_format
# 54       figureqa(cauldron,llava_format)       figureqa_cauldron_llava_format
# 55                   geomverse(cauldron)                   geomverse_cauldron
# 56  hateful_memes(cauldron,llava_format)  hateful_memes_cauldron_llava_format
# 57          hitab(cauldron,llava_format)          hitab_cauldron_llava_format
# 58                         iam(cauldron)                         iam_cauldron
# 59                       raven(cauldron)                       raven_cauldron
# 60         iconqa(cauldron,llava_format)         iconqa_cauldron_llava_format
# 61          infographic_vqa_llava_format         infographic_vqa_llava_format
# 62       intergps(cauldron,llava_format)       intergps_cauldron_llava_format
# 63          mapqa(cauldron,llava_format)          mapqa_cauldron_llava_format
# 64                 multihiertt(cauldron)                 multihiertt_cauldron
# 65               rendered_text(cauldron)               rendered_text_cauldron
# 66                   robut_sqa(cauldron)                   robut_sqa_cauldron
# 67               robut_wikisql(cauldron)               robut_wikisql_cauldron
# 68      robut_wtq(cauldron,llava_format)      robut_wtq_cauldron_llava_format
# 69                screen2words(cauldron)                screen2words_cauldron
# 70      scienceqa(cauldron,llava_format)      scienceqa_cauldron_llava_format
# 71                      tabmwp(cauldron)                      tabmwp_cauldron
# 72        tallyqa(cauldron,llava_format)        tallyqa_cauldron_llava_format
# 73         st_vqa(cauldron,llava_format)         st_vqa_cauldron_llava_format
# 74            tqa(cauldron,llava_format)            tqa_cauldron_llava_format
# 75       visual7w(cauldron,llava_format)       visual7w_cauldron_llava_format
# 76                   visualmrc(cauldron)                   visualmrc_cauldron
# 77         vqarad(cauldron,llava_format)         vqarad_cauldron_llava_format
# 78            vsr(cauldron,llava_format)            vsr_cauldron_llava_format
# 79                     vistext(cauldron)                     vistext_cauldron
# 80                    websight(cauldron)                    websight_cauldron
#
#                                                                                       img_dir  \
# 0                    /data/weka/ellisb/datasets/video/llava_ov_data/images/mavis_math_metagen
# 1                   /data/weka/ellisb/datasets/video/llava_ov_data/images/mavis_math_rule_geo
# 2                          /data/weka/ellisb/datasets/video/llava_ov_data/images/k12_printing
# 3                                /data/weka/ellisb/datasets/video/llava_ov_data/images/iiit5k
# 4                               /data/weka/ellisb/datasets/video/llava_ov_data/images/hme100k
# 5                            /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_gpt4v
# 6                       /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_vqa
# 7                     /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_gpt4v
# 8                             /data/weka/ellisb/datasets/video/llava_ov_data/images/lrv_chart
# 9                   /data/weka/ellisb/datasets/video/llava_ov_data/images/lrv_normal_filtered
# 10               /data/weka/ellisb/datasets/video/llava_ov_data/images/scienceqa_nona_context
# 11              /data/weka/ellisb/datasets/video/llava_ov_data/images/allava_instruct_vflan4v
# 12              /data/weka/ellisb/datasets/video/llava_ov_data/images/allava_instruct_laion4v
# 13                        /data/weka/ellisb/datasets/video/llava_ov_data/images/textocr_gpt4v
# 14                        /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_internvl
# 15                             /data/weka/ellisb/datasets/video/llava_ov_data/images/textcaps
# 16                           /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_qa
# 17                          /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_cap
# 18                           /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_ie
# 19                           /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_kg
# 20                 /data/weka/ellisb/datasets/video/llava_ov_data/images/vision_flan_filtered
# 21                               /data/weka/ellisb/datasets/video/llava_ov_data/images/mathqa
# 22                                /data/weka/ellisb/datasets/video/llava_ov_data/images/geo3k
# 23                           /data/weka/ellisb/datasets/video/llava_ov_data/images/geo170k_qa
# 24                        /data/weka/ellisb/datasets/video/llava_ov_data/images/geo170k_align
# 25                      /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_coco
# 26                 /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_knowledge
# 27                     /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_llava
# 28                       /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_sam
# 29                 /data/weka/ellisb/datasets/video/llava_ov_data/images/CLEVR_Math_MathV360K
# 30                   /data/weka/ellisb/datasets/video/llava_ov_data/images/FigureQA_MathV360K
# 31                 /data/weka/ellisb/datasets/video/llava_ov_data/images/Geometry3K_MathV360K
# 32                     /data/weka/ellisb/datasets/video/llava_ov_data/images/GeoQA__MathV360K
# 33                       /data/weka/ellisb/datasets/video/llava_ov_data/images/GEOS_MathV360K
# 34                     /data/weka/ellisb/datasets/video/llava_ov_data/images/IconQA_MathV360K
# 35                      /data/weka/ellisb/datasets/video/llava_ov_data/images/MapQA_MathV360K
# 36                    /data/weka/ellisb/datasets/video/llava_ov_data/images/PMC_VQA_MathV360K
# 37                /data/weka/ellisb/datasets/video/llava_ov_data/images/Super_CLEVR_MathV360K
# 38                     /data/weka/ellisb/datasets/video/llava_ov_data/images/TabMWP_MathV360K
# 39                     /data/weka/ellisb/datasets/video/llava_ov_data/images/UniGeo_MathV360K
# 40                     /data/weka/ellisb/datasets/video/llava_ov_data/images/VizWiz_MathV360K
# 41              /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_qwen2_72b_st
# 42                 /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_l3_80b_st
# 43                 /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_l3_80b_mt
# 44        /data/weka/ellisb/datasets/video/llava_ov_data/images/image_textualization_filtered
# 45             /data/weka/ellisb/datasets/video/llava_ov_data/images/cambrian_filtered_gpt4vo
# 46                           /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4o
# 47           /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_cauldron_llava_format
# 48         /data/weka/ellisb/datasets/video/llava_ov_data/images/aokvqa_cauldron_llava_format
# 49                  /data/weka/ellisb/datasets/video/llava_ov_data/images/chart2text_cauldron
# 50        /data/weka/ellisb/datasets/video/llava_ov_data/images/chartqa_cauldron_llava_format
# 51          /data/weka/ellisb/datasets/video/llava_ov_data/images/clevr_cauldron_llava_format
# 52       /data/weka/ellisb/datasets/video/llava_ov_data/images/diagram_image_to_text_cauldron
# 53           /data/weka/ellisb/datasets/video/llava_ov_data/images/dvqa_cauldron_llava_format
# 54       /data/weka/ellisb/datasets/video/llava_ov_data/images/figureqa_cauldron_llava_format
# 55                   /data/weka/ellisb/datasets/video/llava_ov_data/images/geomverse_cauldron
# 56  /data/weka/ellisb/datasets/video/llava_ov_data/images/hateful_memes_cauldron_llava_format
# 57          /data/weka/ellisb/datasets/video/llava_ov_data/images/hitab_cauldron_llava_format
# 58                         /data/weka/ellisb/datasets/video/llava_ov_data/images/iam_cauldron
# 59                       /data/weka/ellisb/datasets/video/llava_ov_data/images/raven_cauldron
# 60         /data/weka/ellisb/datasets/video/llava_ov_data/images/iconqa_cauldron_llava_format
# 61         /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_vqa_llava_format
# 62       /data/weka/ellisb/datasets/video/llava_ov_data/images/intergps_cauldron_llava_format
# 63          /data/weka/ellisb/datasets/video/llava_ov_data/images/mapqa_cauldron_llava_format
# 64                 /data/weka/ellisb/datasets/video/llava_ov_data/images/multihiertt_cauldron
# 65               /data/weka/ellisb/datasets/video/llava_ov_data/images/rendered_text_cauldron
# 66                   /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_sqa_cauldron
# 67               /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_wikisql_cauldron
# 68      /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_wtq_cauldron_llava_format
# 69                /data/weka/ellisb/datasets/video/llava_ov_data/images/screen2words_cauldron
# 70      /data/weka/ellisb/datasets/video/llava_ov_data/images/scienceqa_cauldron_llava_format
# 71                      /data/weka/ellisb/datasets/video/llava_ov_data/images/tabmwp_cauldron
# 72        /data/weka/ellisb/datasets/video/llava_ov_data/images/tallyqa_cauldron_llava_format
# 73         /data/weka/ellisb/datasets/video/llava_ov_data/images/st_vqa_cauldron_llava_format
# 74            /data/weka/ellisb/datasets/video/llava_ov_data/images/tqa_cauldron_llava_format
# 75       /data/weka/ellisb/datasets/video/llava_ov_data/images/visual7w_cauldron_llava_format
# 76                   /data/weka/ellisb/datasets/video/llava_ov_data/images/visualmrc_cauldron
# 77         /data/weka/ellisb/datasets/video/llava_ov_data/images/vqarad_cauldron_llava_format
# 78            /data/weka/ellisb/datasets/video/llava_ov_data/images/vsr_cauldron_llava_format
# 79                     /data/weka/ellisb/datasets/video/llava_ov_data/images/vistext_cauldron
# 80                    /data/weka/ellisb/datasets/video/llava_ov_data/images/websight_cauldron
#
#     exists
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16   False
# 17    True
# 18    True
# 19   False
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45   False
# 46    True
# 47    True
# 48    True
# 49    True
# 50    True
# 51    True
# 52    True
# 53    True
# 54    True
# 55    True
# 56    True
# 57    True
# 58    True
# 59    True
# 60    True
# 61    True
# 62    True
# 63    True
# 64    True
# 65    True
# 66    True
# 67    True
# 68    True
# 69    True
# 70    True
# 71    True
# 72    True
# 73    True
# 74    True
# 75    True
# 76    True
# 77    True
# 78    True
# 79    True
# 80    True

# %%
df[df["exists"] == False]
# Out:
#                                                                                                       json_path  \
# 16                                      /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_qa_sft.json
# 19                                      /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_kg_sft.json
# 45  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/cambrian_filtered_gpt4vo_sp_token_fltd_max10k.json
#
#                   short_names               clean_names  \
# 16                 ureader_qa                ureader_qa
# 19                 ureader_kg                ureader_kg
# 45  cambrian(filtered_gpt4vo)  cambrian_filtered_gpt4vo
#
#                                                                            img_dir  \
# 16                /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_qa
# 19                /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_kg
# 45  /data/weka/ellisb/datasets/video/llava_ov_data/images/cambrian_filtered_gpt4vo
#
#     exists
# 16   False
# 19   False
# 45   False

# %%
df2 = df[df["exists"]]
df2
# Out:
#                                                                                                             json_path  \
# 0                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_metagen_87358.json
# 1                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_rule_geo_100000.json
# 2                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/k12_printing_train_256646.json
# 3                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/iiit5k_annotations_2000.json
# 4                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/hme100k_train_clean_74502.json
# 5             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_azuregpt_detailed_understanding_4874.json
# 6                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_vqa_4404.json
# 7                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_azuregpt4v_1992.json
# 8                                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_chart_1787.json
# 9                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_normal_gpt4v_filtered_10500.json
# 10                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/scienceqa_nona_context_19218.json
# 11                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_vflan4v_20000.json
# 12                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_laion4v_50000.json
# 13                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textocr_gpt4v_train_converted_25114.json
# 14                     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_train_internvl_single_12413.json
# 15                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textcaps_train_21952.json
# 17                                           /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_cap_sft.json
# 18                                            /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_ie_sft.json
# 20                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/vision_flan_filtered_186070.json
# 21                                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mathqa_29837.json
# 22                                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo3k_2101.json
# 23                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_qa_converted_67833.json
# 24                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_align_converted_60252.json
# 25                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-coco-50k.json
# 26                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-knowledge-2k.json
# 27                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-llava-30k.json
# 28                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-sam-20k.json
# 29                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_CLEVR-Math_5290.json
# 30                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_FigureQA_17597.json
# 31                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Geometry3K_9734.json
# 32                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GeoQA+_17172.json
# 33                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GEOS_508.json
# 34                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_IconQA_22599.json
# 35                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_MapQA_5235.json
# 36                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PMC-VQA_35958.json
# 37                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Super-CLEVR_8652.json
# 38                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TabMWP_22462.json
# 39                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_UniGeo_11959.json
# 40                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VizWiz_6614.json
# 41  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_qwen2_72b_st_300000_sp_token_fltd_299992.json
# 42                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_st_300000.json
# 43     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_mt_300000_sp_token_fltd_299998.json
# 44                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/image_textualization_dataset_filtered.json
# 46                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4o_dataset.jsonl
# 47                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/ai2d_llava_format_2434.json
# 48                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/aokvqa_16539_llava_format.json
# 49                                             /mnt/bn/vl-research/data/llava_instruct/cauldron/chart2text_26961.json
# 50                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/chartqa_18265_llava_format.json
# 51                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/clevr_70000_llava_format.json
# 52                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/diagram_image_to_text_300.json
# 53                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/dvqa_200000_llava_format.json
# 54                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/figureqa_100000_llava_format.json
# 55                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/geomverse_9303.json
# 56                              /mnt/bn/vl-research/data/llava_instruct/cauldron/hateful_memes_8500_llava_format.json
# 57                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/hitab_2500_llava_format.json
# 58                                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/iam_5663.json
# 59                                                  /mnt/bn/vl-research/data/llava_instruct/cauldron/raven_42000.json
# 60                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/iconqa_llava_format_27307.json
# 61                            /mnt/bn/vl-research/data/llava_instruct/cauldron/infographic_vqa_2118_llava_format.json
# 62                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/intergps_1280_llava_format.json
# 63                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/mapqa_37417_llava_format.json
# 64                                             /mnt/bn/vl-research/data/llava_instruct/cauldron/multihiertt_7619.json
# 65                                          /mnt/bn/vl-research/data/llava_instruct/cauldron/rendered_text_10000.json
# 66                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_sqa_8514.json
# 67                                          /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wikisql_74989.json
# 68                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wtq_38246_llava_format.json
# 69                                           /mnt/bn/vl-research/data/llava_instruct/cauldron/screen2words_15730.json
# 70                                  /mnt/bn/vl-research/data/llava_instruct/cauldron/scienceqa_llava_format_4976.json
# 71                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/tabmwp_22722.json
# 72                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/tallyqa_98680_llava_format.json
# 73                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/st_vqa_17247_llava_format.json
# 74                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/tqa_llava_format_27307.json
# 75                                  /mnt/bn/vl-research/data/llava_instruct/cauldron/visual7w_llava_format_14366.json
# 76                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/visualmrc_3027.json
# 77                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/vqarad_313_llava_format.json
# 78                                        /mnt/bn/vl-research/data/llava_instruct/cauldron/vsr_2157_llava_format.json
# 79                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/vistext_9969.json
# 80                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/websight_10000.json
#
#                              short_names                          clean_names  \
# 0                     mavis_math_metagen                   mavis_math_metagen
# 1                    mavis_math_rule_geo                  mavis_math_rule_geo
# 2                           k12_printing                         k12_printing
# 3                                 iiit5k                               iiit5k
# 4                                hme100k                              hme100k
# 5                            ai2d(gpt4v)                           ai2d_gpt4v
# 6                        infographic_vqa                      infographic_vqa
# 7                     infographic(gpt4v)                    infographic_gpt4v
# 8                              lrv_chart                            lrv_chart
# 9                   lrv_normal(filtered)                  lrv_normal_filtered
# 10               scienceqa(nona_context)               scienceqa_nona_context
# 11               allava_instruct_vflan4v              allava_instruct_vflan4v
# 12               allava_instruct_laion4v              allava_instruct_laion4v
# 13                        textocr(gpt4v)                        textocr_gpt4v
# 14                        ai2d(internvl)                        ai2d_internvl
# 15                              textcaps                             textcaps
# 17                           ureader_cap                          ureader_cap
# 18                            ureader_ie                           ureader_ie
# 20                 vision_flan(filtered)                 vision_flan_filtered
# 21                                mathqa                               mathqa
# 22                                 geo3k                                geo3k
# 23                           geo170k(qa)                           geo170k_qa
# 24                        geo170k(align)                        geo170k_align
# 25                      sharegpt4v(coco)                      sharegpt4v_coco
# 26                 sharegpt4v(knowledge)                 sharegpt4v_knowledge
# 27                     sharegpt4v(llava)                     sharegpt4v_llava
# 28                       sharegpt4v(sam)                       sharegpt4v_sam
# 29                 CLEVR-Math(MathV360K)                 CLEVR_Math_MathV360K
# 30                   FigureQA(MathV360K)                   FigureQA_MathV360K
# 31                 Geometry3K(MathV360K)                 Geometry3K_MathV360K
# 32                     GeoQA+(MathV360K)                     GeoQA__MathV360K
# 33                       GEOS(MathV360K)                       GEOS_MathV360K
# 34                     IconQA(MathV360K)                     IconQA_MathV360K
# 35                      MapQA(MathV360K)                      MapQA_MathV360K
# 36                    PMC-VQA(MathV360K)                    PMC_VQA_MathV360K
# 37                Super-CLEVR(MathV360K)                Super_CLEVR_MathV360K
# 38                     TabMWP(MathV360K)                     TabMWP_MathV360K
# 39                     UniGeo(MathV360K)                     UniGeo_MathV360K
# 40                     VizWiz(MathV360K)                     VizWiz_MathV360K
# 41              magpie_pro(qwen2_72b_st)              magpie_pro_qwen2_72b_st
# 42                 magpie_pro(l3_80b_st)                 magpie_pro_l3_80b_st
# 43                 magpie_pro(l3_80b_mt)                 magpie_pro_l3_80b_mt
# 44        image_textualization(filtered)        image_textualization_filtered
# 46                            sharegpt4o                           sharegpt4o
# 47           ai2d(cauldron,llava_format)           ai2d_cauldron_llava_format
# 48         aokvqa(cauldron,llava_format)         aokvqa_cauldron_llava_format
# 49                  chart2text(cauldron)                  chart2text_cauldron
# 50        chartqa(cauldron,llava_format)        chartqa_cauldron_llava_format
# 51          clevr(cauldron,llava_format)          clevr_cauldron_llava_format
# 52       diagram_image_to_text(cauldron)       diagram_image_to_text_cauldron
# 53           dvqa(cauldron,llava_format)           dvqa_cauldron_llava_format
# 54       figureqa(cauldron,llava_format)       figureqa_cauldron_llava_format
# 55                   geomverse(cauldron)                   geomverse_cauldron
# 56  hateful_memes(cauldron,llava_format)  hateful_memes_cauldron_llava_format
# 57          hitab(cauldron,llava_format)          hitab_cauldron_llava_format
# 58                         iam(cauldron)                         iam_cauldron
# 59                       raven(cauldron)                       raven_cauldron
# 60         iconqa(cauldron,llava_format)         iconqa_cauldron_llava_format
# 61          infographic_vqa_llava_format         infographic_vqa_llava_format
# 62       intergps(cauldron,llava_format)       intergps_cauldron_llava_format
# 63          mapqa(cauldron,llava_format)          mapqa_cauldron_llava_format
# 64                 multihiertt(cauldron)                 multihiertt_cauldron
# 65               rendered_text(cauldron)               rendered_text_cauldron
# 66                   robut_sqa(cauldron)                   robut_sqa_cauldron
# 67               robut_wikisql(cauldron)               robut_wikisql_cauldron
# 68      robut_wtq(cauldron,llava_format)      robut_wtq_cauldron_llava_format
# 69                screen2words(cauldron)                screen2words_cauldron
# 70      scienceqa(cauldron,llava_format)      scienceqa_cauldron_llava_format
# 71                      tabmwp(cauldron)                      tabmwp_cauldron
# 72        tallyqa(cauldron,llava_format)        tallyqa_cauldron_llava_format
# 73         st_vqa(cauldron,llava_format)         st_vqa_cauldron_llava_format
# 74            tqa(cauldron,llava_format)            tqa_cauldron_llava_format
# 75       visual7w(cauldron,llava_format)       visual7w_cauldron_llava_format
# 76                   visualmrc(cauldron)                   visualmrc_cauldron
# 77         vqarad(cauldron,llava_format)         vqarad_cauldron_llava_format
# 78            vsr(cauldron,llava_format)            vsr_cauldron_llava_format
# 79                     vistext(cauldron)                     vistext_cauldron
# 80                    websight(cauldron)                    websight_cauldron
#
#                                                                                       img_dir  \
# 0                    /data/weka/ellisb/datasets/video/llava_ov_data/images/mavis_math_metagen
# 1                   /data/weka/ellisb/datasets/video/llava_ov_data/images/mavis_math_rule_geo
# 2                          /data/weka/ellisb/datasets/video/llava_ov_data/images/k12_printing
# 3                                /data/weka/ellisb/datasets/video/llava_ov_data/images/iiit5k
# 4                               /data/weka/ellisb/datasets/video/llava_ov_data/images/hme100k
# 5                            /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_gpt4v
# 6                       /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_vqa
# 7                     /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_gpt4v
# 8                             /data/weka/ellisb/datasets/video/llava_ov_data/images/lrv_chart
# 9                   /data/weka/ellisb/datasets/video/llava_ov_data/images/lrv_normal_filtered
# 10               /data/weka/ellisb/datasets/video/llava_ov_data/images/scienceqa_nona_context
# 11              /data/weka/ellisb/datasets/video/llava_ov_data/images/allava_instruct_vflan4v
# 12              /data/weka/ellisb/datasets/video/llava_ov_data/images/allava_instruct_laion4v
# 13                        /data/weka/ellisb/datasets/video/llava_ov_data/images/textocr_gpt4v
# 14                        /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_internvl
# 15                             /data/weka/ellisb/datasets/video/llava_ov_data/images/textcaps
# 17                          /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_cap
# 18                           /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_ie
# 20                 /data/weka/ellisb/datasets/video/llava_ov_data/images/vision_flan_filtered
# 21                               /data/weka/ellisb/datasets/video/llava_ov_data/images/mathqa
# 22                                /data/weka/ellisb/datasets/video/llava_ov_data/images/geo3k
# 23                           /data/weka/ellisb/datasets/video/llava_ov_data/images/geo170k_qa
# 24                        /data/weka/ellisb/datasets/video/llava_ov_data/images/geo170k_align
# 25                      /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_coco
# 26                 /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_knowledge
# 27                     /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_llava
# 28                       /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_sam
# 29                 /data/weka/ellisb/datasets/video/llava_ov_data/images/CLEVR_Math_MathV360K
# 30                   /data/weka/ellisb/datasets/video/llava_ov_data/images/FigureQA_MathV360K
# 31                 /data/weka/ellisb/datasets/video/llava_ov_data/images/Geometry3K_MathV360K
# 32                     /data/weka/ellisb/datasets/video/llava_ov_data/images/GeoQA__MathV360K
# 33                       /data/weka/ellisb/datasets/video/llava_ov_data/images/GEOS_MathV360K
# 34                     /data/weka/ellisb/datasets/video/llava_ov_data/images/IconQA_MathV360K
# 35                      /data/weka/ellisb/datasets/video/llava_ov_data/images/MapQA_MathV360K
# 36                    /data/weka/ellisb/datasets/video/llava_ov_data/images/PMC_VQA_MathV360K
# 37                /data/weka/ellisb/datasets/video/llava_ov_data/images/Super_CLEVR_MathV360K
# 38                     /data/weka/ellisb/datasets/video/llava_ov_data/images/TabMWP_MathV360K
# 39                     /data/weka/ellisb/datasets/video/llava_ov_data/images/UniGeo_MathV360K
# 40                     /data/weka/ellisb/datasets/video/llava_ov_data/images/VizWiz_MathV360K
# 41              /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_qwen2_72b_st
# 42                 /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_l3_80b_st
# 43                 /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_l3_80b_mt
# 44        /data/weka/ellisb/datasets/video/llava_ov_data/images/image_textualization_filtered
# 46                           /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4o
# 47           /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_cauldron_llava_format
# 48         /data/weka/ellisb/datasets/video/llava_ov_data/images/aokvqa_cauldron_llava_format
# 49                  /data/weka/ellisb/datasets/video/llava_ov_data/images/chart2text_cauldron
# 50        /data/weka/ellisb/datasets/video/llava_ov_data/images/chartqa_cauldron_llava_format
# 51          /data/weka/ellisb/datasets/video/llava_ov_data/images/clevr_cauldron_llava_format
# 52       /data/weka/ellisb/datasets/video/llava_ov_data/images/diagram_image_to_text_cauldron
# 53           /data/weka/ellisb/datasets/video/llava_ov_data/images/dvqa_cauldron_llava_format
# 54       /data/weka/ellisb/datasets/video/llava_ov_data/images/figureqa_cauldron_llava_format
# 55                   /data/weka/ellisb/datasets/video/llava_ov_data/images/geomverse_cauldron
# 56  /data/weka/ellisb/datasets/video/llava_ov_data/images/hateful_memes_cauldron_llava_format
# 57          /data/weka/ellisb/datasets/video/llava_ov_data/images/hitab_cauldron_llava_format
# 58                         /data/weka/ellisb/datasets/video/llava_ov_data/images/iam_cauldron
# 59                       /data/weka/ellisb/datasets/video/llava_ov_data/images/raven_cauldron
# 60         /data/weka/ellisb/datasets/video/llava_ov_data/images/iconqa_cauldron_llava_format
# 61         /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_vqa_llava_format
# 62       /data/weka/ellisb/datasets/video/llava_ov_data/images/intergps_cauldron_llava_format
# 63          /data/weka/ellisb/datasets/video/llava_ov_data/images/mapqa_cauldron_llava_format
# 64                 /data/weka/ellisb/datasets/video/llava_ov_data/images/multihiertt_cauldron
# 65               /data/weka/ellisb/datasets/video/llava_ov_data/images/rendered_text_cauldron
# 66                   /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_sqa_cauldron
# 67               /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_wikisql_cauldron
# 68      /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_wtq_cauldron_llava_format
# 69                /data/weka/ellisb/datasets/video/llava_ov_data/images/screen2words_cauldron
# 70      /data/weka/ellisb/datasets/video/llava_ov_data/images/scienceqa_cauldron_llava_format
# 71                      /data/weka/ellisb/datasets/video/llava_ov_data/images/tabmwp_cauldron
# 72        /data/weka/ellisb/datasets/video/llava_ov_data/images/tallyqa_cauldron_llava_format
# 73         /data/weka/ellisb/datasets/video/llava_ov_data/images/st_vqa_cauldron_llava_format
# 74            /data/weka/ellisb/datasets/video/llava_ov_data/images/tqa_cauldron_llava_format
# 75       /data/weka/ellisb/datasets/video/llava_ov_data/images/visual7w_cauldron_llava_format
# 76                   /data/weka/ellisb/datasets/video/llava_ov_data/images/visualmrc_cauldron
# 77         /data/weka/ellisb/datasets/video/llava_ov_data/images/vqarad_cauldron_llava_format
# 78            /data/weka/ellisb/datasets/video/llava_ov_data/images/vsr_cauldron_llava_format
# 79                     /data/weka/ellisb/datasets/video/llava_ov_data/images/vistext_cauldron
# 80                    /data/weka/ellisb/datasets/video/llava_ov_data/images/websight_cauldron
#
#     exists
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 17    True
# 18    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 46    True
# 47    True
# 48    True
# 49    True
# 50    True
# 51    True
# 52    True
# 53    True
# 54    True
# 55    True
# 56    True
# 57    True
# 58    True
# 59    True
# 60    True
# 61    True
# 62    True
# 63    True
# 64    True
# 65    True
# 66    True
# 67    True
# 68    True
# 69    True
# 70    True
# 71    True
# 72    True
# 73    True
# 74    True
# 75    True
# 76    True
# 77    True
# 78    True
# 79    True
# 80    True

# %%
ov_yaml = "./onevision.yaml"
with open(ov_yaml, "r") as f:
    ov = yaml.safe_load(f)

print(f"Original onevision.yaml: {str(ov)[:100]}")
# Out:
# Original onevision.yaml: {'datasets': [{'json_path': '/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_next_fit

# %%
ov["datasets"][0]
# Out:
# {'json_path': '/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_next_fit_mix_filtered_text_wild_738590.json',
#  'sampling_strategy': 'first:50%'}

# %%
ov_df = pd.DataFrame(ov["datasets"])
ov_df
# Out:
#                                                                                                               json_path  \
# 0            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_next_fit_mix_filtered_text_wild_738590.json
# 1                                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_wild_4v_39k.json
# 2                                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_wild_4v_12k.json
# 3                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_metagen_87358.json
# 4                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_rule_geo_100000.json
# 5   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/cambrian_filtered_gpt4vo_sp_token_fltd_max10k_checked.json
# 6                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/VisualWebInstruct_filtered_263589.json
# 7                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/visual_chat_en_26048_gpt4o_coco_checked.json
# 8                                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llavar_gpt4_20k.json
# 9               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_azuregpt_detailed_understanding_4874.json
# 10                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_vqa_4404.json
# 11                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_azuregpt4v_1992.json
# 12                                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_chart_1787.json
# 13                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_normal_gpt4v_filtered_10500.json
# 14                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_vflan4v_20000.json
# 15                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_laion4v_50000.json
# 16                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textocr_gpt4v_train_converted_25114.json
# 17                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_train_internvl_single_12413.json
# 18                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textcaps_train_21952.json
# 19                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_qa_sft.json
# 20                                             /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_cap_sft.json
# 21                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_ie_sft.json
# 22                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_kg_sft.json
# 23                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/vision_flan_filtered_186070.json
# 24                                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mathqa_29837.json
# 25                                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo3k_2101.json
# 26                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_qa_converted_67833.json
# 27                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_align_converted_60252.json
# 28                                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4o_dataset.jsonl
# 29                                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-coco-50k.json
# 30                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-knowledge-2k.json
# 31                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-llava-30k.json
# 32                                     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-sam-20k.json
# 33                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_CLEVR-Math_5290.json
# 34                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_FigureQA_17597.json
# 35                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Geometry3K_9734.json
# 36                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GeoQA+_17172.json
# 37                                     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GEOS_508.json
# 38                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_IconQA_22599.json
# 39                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_MapQA_5235.json
# 40                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PlotQA_5485.json
# 41                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PMC-VQA_35958.json
# 42                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Super-CLEVR_8652.json
# 43                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TabMWP_22462.json
# 44                                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TQA_10181.json
# 45                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_UniGeo_11959.json
# 46                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VizWiz_6614.json
# 47                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VQA-AS_5907.json
# 48                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VQA-RAD_2130.json
# 49    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_qwen2_72b_st_300000_sp_token_fltd_299992.json
# 50                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_st_300000.json
# 51       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_mt_300000_sp_token_fltd_299998.json
# 52                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/image_textualization_dataset_filtered.json
# 53                                         /mnt/bn/vl-research/data/llava_instruct/cauldron/ai2d_llava_format_2434.json
# 54                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/chart2text_26961.json
# 55                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/chartqa_18265_llava_format.json
# 56                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/diagram_image_to_text_300.json
# 57                                /mnt/bn/vl-research/data/llava_instruct/cauldron/hateful_memes_8500_llava_format.json
# 58                                        /mnt/bn/vl-research/data/llava_instruct/cauldron/hitab_2500_llava_format.json
# 59                                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/iam_5663.json
# 60                              /mnt/bn/vl-research/data/llava_instruct/cauldron/infographic_vqa_2118_llava_format.json
# 61                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/intergps_1280_llava_format.json
# 62                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/mapqa_37417_llava_format.json
# 63                                            /mnt/bn/vl-research/data/llava_instruct/cauldron/rendered_text_10000.json
# 64                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_sqa_8514.json
# 65                                            /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wikisql_74989.json
# 66                                             /mnt/bn/vl-research/data/llava_instruct/cauldron/screen2words_15730.json
# 67                                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/tabmwp_22722.json
# 68                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/tallyqa_98680_llava_format.json
# 69                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/st_vqa_17247_llava_format.json
# 70                                         /mnt/bn/vl-research/data/llava_instruct/cauldron/tqa_llava_format_27307.json
# 71                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/visual7w_llava_format_14366.json
# 72                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/visualmrc_3027.json
# 73                                        /mnt/bn/vl-research/data/llava_instruct/cauldron/vqarad_313_llava_format.json
# 74                                          /mnt/bn/vl-research/data/llava_instruct/cauldron/vsr_2157_llava_format.json
# 75                                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/vistext_9969.json
# 76                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/websight_10000.json
# 77                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_ofa_DEMON-FULL_filtered_311085.json
# 78                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_ofa_mantis-instruct_reformatted.json
# 79                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/academic_source_30s_v1_all.json
# 80                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/0718_0_30_s_academic_mc_v0_1_all.json
# 81                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4video_255000.json
#
#    sampling_strategy
# 0          first:50%
# 1          first:10%
# 2          first:10%
# 3          first:10%
# 4          first:10%
# 5                all
# 6                all
# 7                all
# 8          first:10%
# 9                all
# 10               all
# 11               all
# 12               all
# 13         first:10%
# 14         first:30%
# 15         first:30%
# 16         first:10%
# 17         first:10%
# 18         first:10%
# 19         first:10%
# 20         first:10%
# 21         first:10%
# 22         first:10%
# 23               all
# 24               all
# 25               all
# 26         first:10%
# 27         first:10%
# 28               all
# 29               all
# 30               all
# 31               all
# 32               all
# 33         first:10%
# 34         first:10%
# 35         first:10%
# 36         first:10%
# 37               all
# 38          first:5%
# 39         first:10%
# 40         first:10%
# 41          first:1%
# 42         first:10%
# 43         first:10%
# 44         first:10%
# 45         first:10%
# 46         first:10%
# 47         first:10%
# 48         first:10%
# 49           end:20%
# 50           end:20%
# 51           end:20%
# 52         first:20%
# 53               all
# 54         first:10%
# 55         first:10%
# 56               all
# 57         first:10%
# 58         first:10%
# 59         first:10%
# 60         first:10%
# 61         first:10%
# 62         first:10%
# 63         first:10%
# 64         first:10%
# 65         first:10%
# 66         first:10%
# 67          first:5%
# 68          first:5%
# 69         first:10%
# 70          first:5%
# 71         first:10%
# 72         first:10%
# 73         first:10%
# 74         first:10%
# 75         first:10%
# 76         first:10%
# 77               all
# 78               all
# 79               all
# 80               all
# 81               all

# %%
# left join the two dataframes, keeping all rows from the original onevision.yaml
# merged_df = ov_df.merge(df2, how="left", left_on="json_path", right_on="json_path")
merged_df = ov_df.merge(df2, how="left", on="json_path")
merged_df
# Out:
#                                                                                                               json_path  \
# 0            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_next_fit_mix_filtered_text_wild_738590.json
# 1                                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_wild_4v_39k.json
# 2                                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_wild_4v_12k.json
# 3                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_metagen_87358.json
# 4                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_rule_geo_100000.json
# 5   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/cambrian_filtered_gpt4vo_sp_token_fltd_max10k_checked.json
# 6                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/VisualWebInstruct_filtered_263589.json
# 7                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/visual_chat_en_26048_gpt4o_coco_checked.json
# 8                                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llavar_gpt4_20k.json
# 9               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_azuregpt_detailed_understanding_4874.json
# 10                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_vqa_4404.json
# 11                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_azuregpt4v_1992.json
# 12                                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_chart_1787.json
# 13                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_normal_gpt4v_filtered_10500.json
# 14                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_vflan4v_20000.json
# 15                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_laion4v_50000.json
# 16                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textocr_gpt4v_train_converted_25114.json
# 17                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_train_internvl_single_12413.json
# 18                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textcaps_train_21952.json
# 19                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_qa_sft.json
# 20                                             /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_cap_sft.json
# 21                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_ie_sft.json
# 22                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_kg_sft.json
# 23                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/vision_flan_filtered_186070.json
# 24                                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mathqa_29837.json
# 25                                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo3k_2101.json
# 26                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_qa_converted_67833.json
# 27                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_align_converted_60252.json
# 28                                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4o_dataset.jsonl
# 29                                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-coco-50k.json
# 30                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-knowledge-2k.json
# 31                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-llava-30k.json
# 32                                     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-sam-20k.json
# 33                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_CLEVR-Math_5290.json
# 34                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_FigureQA_17597.json
# 35                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Geometry3K_9734.json
# 36                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GeoQA+_17172.json
# 37                                     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GEOS_508.json
# 38                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_IconQA_22599.json
# 39                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_MapQA_5235.json
# 40                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PlotQA_5485.json
# 41                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PMC-VQA_35958.json
# 42                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Super-CLEVR_8652.json
# 43                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TabMWP_22462.json
# 44                                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TQA_10181.json
# 45                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_UniGeo_11959.json
# 46                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VizWiz_6614.json
# 47                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VQA-AS_5907.json
# 48                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VQA-RAD_2130.json
# 49    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_qwen2_72b_st_300000_sp_token_fltd_299992.json
# 50                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_st_300000.json
# 51       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_mt_300000_sp_token_fltd_299998.json
# 52                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/image_textualization_dataset_filtered.json
# 53                                         /mnt/bn/vl-research/data/llava_instruct/cauldron/ai2d_llava_format_2434.json
# 54                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/chart2text_26961.json
# 55                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/chartqa_18265_llava_format.json
# 56                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/diagram_image_to_text_300.json
# 57                                /mnt/bn/vl-research/data/llava_instruct/cauldron/hateful_memes_8500_llava_format.json
# 58                                        /mnt/bn/vl-research/data/llava_instruct/cauldron/hitab_2500_llava_format.json
# 59                                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/iam_5663.json
# 60                              /mnt/bn/vl-research/data/llava_instruct/cauldron/infographic_vqa_2118_llava_format.json
# 61                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/intergps_1280_llava_format.json
# 62                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/mapqa_37417_llava_format.json
# 63                                            /mnt/bn/vl-research/data/llava_instruct/cauldron/rendered_text_10000.json
# 64                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_sqa_8514.json
# 65                                            /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wikisql_74989.json
# 66                                             /mnt/bn/vl-research/data/llava_instruct/cauldron/screen2words_15730.json
# 67                                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/tabmwp_22722.json
# 68                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/tallyqa_98680_llava_format.json
# 69                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/st_vqa_17247_llava_format.json
# 70                                         /mnt/bn/vl-research/data/llava_instruct/cauldron/tqa_llava_format_27307.json
# 71                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/visual7w_llava_format_14366.json
# 72                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/visualmrc_3027.json
# 73                                        /mnt/bn/vl-research/data/llava_instruct/cauldron/vqarad_313_llava_format.json
# 74                                          /mnt/bn/vl-research/data/llava_instruct/cauldron/vsr_2157_llava_format.json
# 75                                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/vistext_9969.json
# 76                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/websight_10000.json
# 77                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_ofa_DEMON-FULL_filtered_311085.json
# 78                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_ofa_mantis-instruct_reformatted.json
# 79                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/academic_source_30s_v1_all.json
# 80                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/0718_0_30_s_academic_mc_v0_1_all.json
# 81                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4video_255000.json
#
#    sampling_strategy                           short_names  \
# 0          first:50%                                   NaN
# 1          first:10%                                   NaN
# 2          first:10%                                   NaN
# 3          first:10%                    mavis_math_metagen
# 4          first:10%                   mavis_math_rule_geo
# 5                all                                   NaN
# 6                all                                   NaN
# 7                all                                   NaN
# 8          first:10%                                   NaN
# 9                all                           ai2d(gpt4v)
# 10               all                       infographic_vqa
# 11               all                    infographic(gpt4v)
# 12               all                             lrv_chart
# 13         first:10%                  lrv_normal(filtered)
# 14         first:30%               allava_instruct_vflan4v
# 15         first:30%               allava_instruct_laion4v
# 16         first:10%                        textocr(gpt4v)
# 17         first:10%                        ai2d(internvl)
# 18         first:10%                              textcaps
# 19         first:10%                                   NaN
# 20         first:10%                           ureader_cap
# 21         first:10%                            ureader_ie
# 22         first:10%                                   NaN
# 23               all                 vision_flan(filtered)
# 24               all                                mathqa
# 25               all                                 geo3k
# 26         first:10%                           geo170k(qa)
# 27         first:10%                        geo170k(align)
# 28               all                            sharegpt4o
# 29               all                      sharegpt4v(coco)
# 30               all                 sharegpt4v(knowledge)
# 31               all                     sharegpt4v(llava)
# 32               all                       sharegpt4v(sam)
# 33         first:10%                 CLEVR-Math(MathV360K)
# 34         first:10%                   FigureQA(MathV360K)
# 35         first:10%                 Geometry3K(MathV360K)
# 36         first:10%                     GeoQA+(MathV360K)
# 37               all                       GEOS(MathV360K)
# 38          first:5%                     IconQA(MathV360K)
# 39         first:10%                      MapQA(MathV360K)
# 40         first:10%                                   NaN
# 41          first:1%                    PMC-VQA(MathV360K)
# 42         first:10%                Super-CLEVR(MathV360K)
# 43         first:10%                     TabMWP(MathV360K)
# 44         first:10%                                   NaN
# 45         first:10%                     UniGeo(MathV360K)
# 46         first:10%                     VizWiz(MathV360K)
# 47         first:10%                                   NaN
# 48         first:10%                                   NaN
# 49           end:20%              magpie_pro(qwen2_72b_st)
# 50           end:20%                 magpie_pro(l3_80b_st)
# 51           end:20%                 magpie_pro(l3_80b_mt)
# 52         first:20%        image_textualization(filtered)
# 53               all           ai2d(cauldron,llava_format)
# 54         first:10%                  chart2text(cauldron)
# 55         first:10%        chartqa(cauldron,llava_format)
# 56               all       diagram_image_to_text(cauldron)
# 57         first:10%  hateful_memes(cauldron,llava_format)
# 58         first:10%          hitab(cauldron,llava_format)
# 59         first:10%                         iam(cauldron)
# 60         first:10%          infographic_vqa_llava_format
# 61         first:10%       intergps(cauldron,llava_format)
# 62         first:10%          mapqa(cauldron,llava_format)
# 63         first:10%               rendered_text(cauldron)
# 64         first:10%                   robut_sqa(cauldron)
# 65         first:10%               robut_wikisql(cauldron)
# 66         first:10%                screen2words(cauldron)
# 67          first:5%                      tabmwp(cauldron)
# 68          first:5%        tallyqa(cauldron,llava_format)
# 69         first:10%         st_vqa(cauldron,llava_format)
# 70          first:5%            tqa(cauldron,llava_format)
# 71         first:10%       visual7w(cauldron,llava_format)
# 72         first:10%                   visualmrc(cauldron)
# 73         first:10%         vqarad(cauldron,llava_format)
# 74         first:10%            vsr(cauldron,llava_format)
# 75         first:10%                     vistext(cauldron)
# 76         first:10%                    websight(cauldron)
# 77               all                                   NaN
# 78               all                                   NaN
# 79               all                                   NaN
# 80               all                                   NaN
# 81               all                                   NaN
#
#                             clean_names  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                    mavis_math_metagen
# 4                   mavis_math_rule_geo
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                            ai2d_gpt4v
# 10                      infographic_vqa
# 11                    infographic_gpt4v
# 12                            lrv_chart
# 13                  lrv_normal_filtered
# 14              allava_instruct_vflan4v
# 15              allava_instruct_laion4v
# 16                        textocr_gpt4v
# 17                        ai2d_internvl
# 18                             textcaps
# 19                                  NaN
# 20                          ureader_cap
# 21                           ureader_ie
# 22                                  NaN
# 23                 vision_flan_filtered
# 24                               mathqa
# 25                                geo3k
# 26                           geo170k_qa
# 27                        geo170k_align
# 28                           sharegpt4o
# 29                      sharegpt4v_coco
# 30                 sharegpt4v_knowledge
# 31                     sharegpt4v_llava
# 32                       sharegpt4v_sam
# 33                 CLEVR_Math_MathV360K
# 34                   FigureQA_MathV360K
# 35                 Geometry3K_MathV360K
# 36                     GeoQA__MathV360K
# 37                       GEOS_MathV360K
# 38                     IconQA_MathV360K
# 39                      MapQA_MathV360K
# 40                                  NaN
# 41                    PMC_VQA_MathV360K
# 42                Super_CLEVR_MathV360K
# 43                     TabMWP_MathV360K
# 44                                  NaN
# 45                     UniGeo_MathV360K
# 46                     VizWiz_MathV360K
# 47                                  NaN
# 48                                  NaN
# 49              magpie_pro_qwen2_72b_st
# 50                 magpie_pro_l3_80b_st
# 51                 magpie_pro_l3_80b_mt
# 52        image_textualization_filtered
# 53           ai2d_cauldron_llava_format
# 54                  chart2text_cauldron
# 55        chartqa_cauldron_llava_format
# 56       diagram_image_to_text_cauldron
# 57  hateful_memes_cauldron_llava_format
# 58          hitab_cauldron_llava_format
# 59                         iam_cauldron
# 60         infographic_vqa_llava_format
# 61       intergps_cauldron_llava_format
# 62          mapqa_cauldron_llava_format
# 63               rendered_text_cauldron
# 64                   robut_sqa_cauldron
# 65               robut_wikisql_cauldron
# 66                screen2words_cauldron
# 67                      tabmwp_cauldron
# 68        tallyqa_cauldron_llava_format
# 69         st_vqa_cauldron_llava_format
# 70            tqa_cauldron_llava_format
# 71       visual7w_cauldron_llava_format
# 72                   visualmrc_cauldron
# 73         vqarad_cauldron_llava_format
# 74            vsr_cauldron_llava_format
# 75                     vistext_cauldron
# 76                    websight_cauldron
# 77                                  NaN
# 78                                  NaN
# 79                                  NaN
# 80                                  NaN
# 81                                  NaN
#
#                                                                                       img_dir  \
# 0                                                                                         NaN
# 1                                                                                         NaN
# 2                                                                                         NaN
# 3                    /data/weka/ellisb/datasets/video/llava_ov_data/images/mavis_math_metagen
# 4                   /data/weka/ellisb/datasets/video/llava_ov_data/images/mavis_math_rule_geo
# 5                                                                                         NaN
# 6                                                                                         NaN
# 7                                                                                         NaN
# 8                                                                                         NaN
# 9                            /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_gpt4v
# 10                      /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_vqa
# 11                    /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_gpt4v
# 12                            /data/weka/ellisb/datasets/video/llava_ov_data/images/lrv_chart
# 13                  /data/weka/ellisb/datasets/video/llava_ov_data/images/lrv_normal_filtered
# 14              /data/weka/ellisb/datasets/video/llava_ov_data/images/allava_instruct_vflan4v
# 15              /data/weka/ellisb/datasets/video/llava_ov_data/images/allava_instruct_laion4v
# 16                        /data/weka/ellisb/datasets/video/llava_ov_data/images/textocr_gpt4v
# 17                        /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_internvl
# 18                             /data/weka/ellisb/datasets/video/llava_ov_data/images/textcaps
# 19                                                                                        NaN
# 20                          /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_cap
# 21                           /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_ie
# 22                                                                                        NaN
# 23                 /data/weka/ellisb/datasets/video/llava_ov_data/images/vision_flan_filtered
# 24                               /data/weka/ellisb/datasets/video/llava_ov_data/images/mathqa
# 25                                /data/weka/ellisb/datasets/video/llava_ov_data/images/geo3k
# 26                           /data/weka/ellisb/datasets/video/llava_ov_data/images/geo170k_qa
# 27                        /data/weka/ellisb/datasets/video/llava_ov_data/images/geo170k_align
# 28                           /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4o
# 29                      /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_coco
# 30                 /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_knowledge
# 31                     /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_llava
# 32                       /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_sam
# 33                 /data/weka/ellisb/datasets/video/llava_ov_data/images/CLEVR_Math_MathV360K
# 34                   /data/weka/ellisb/datasets/video/llava_ov_data/images/FigureQA_MathV360K
# 35                 /data/weka/ellisb/datasets/video/llava_ov_data/images/Geometry3K_MathV360K
# 36                     /data/weka/ellisb/datasets/video/llava_ov_data/images/GeoQA__MathV360K
# 37                       /data/weka/ellisb/datasets/video/llava_ov_data/images/GEOS_MathV360K
# 38                     /data/weka/ellisb/datasets/video/llava_ov_data/images/IconQA_MathV360K
# 39                      /data/weka/ellisb/datasets/video/llava_ov_data/images/MapQA_MathV360K
# 40                                                                                        NaN
# 41                    /data/weka/ellisb/datasets/video/llava_ov_data/images/PMC_VQA_MathV360K
# 42                /data/weka/ellisb/datasets/video/llava_ov_data/images/Super_CLEVR_MathV360K
# 43                     /data/weka/ellisb/datasets/video/llava_ov_data/images/TabMWP_MathV360K
# 44                                                                                        NaN
# 45                     /data/weka/ellisb/datasets/video/llava_ov_data/images/UniGeo_MathV360K
# 46                     /data/weka/ellisb/datasets/video/llava_ov_data/images/VizWiz_MathV360K
# 47                                                                                        NaN
# 48                                                                                        NaN
# 49              /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_qwen2_72b_st
# 50                 /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_l3_80b_st
# 51                 /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_l3_80b_mt
# 52        /data/weka/ellisb/datasets/video/llava_ov_data/images/image_textualization_filtered
# 53           /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_cauldron_llava_format
# 54                  /data/weka/ellisb/datasets/video/llava_ov_data/images/chart2text_cauldron
# 55        /data/weka/ellisb/datasets/video/llava_ov_data/images/chartqa_cauldron_llava_format
# 56       /data/weka/ellisb/datasets/video/llava_ov_data/images/diagram_image_to_text_cauldron
# 57  /data/weka/ellisb/datasets/video/llava_ov_data/images/hateful_memes_cauldron_llava_format
# 58          /data/weka/ellisb/datasets/video/llava_ov_data/images/hitab_cauldron_llava_format
# 59                         /data/weka/ellisb/datasets/video/llava_ov_data/images/iam_cauldron
# 60         /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_vqa_llava_format
# 61       /data/weka/ellisb/datasets/video/llava_ov_data/images/intergps_cauldron_llava_format
# 62          /data/weka/ellisb/datasets/video/llava_ov_data/images/mapqa_cauldron_llava_format
# 63               /data/weka/ellisb/datasets/video/llava_ov_data/images/rendered_text_cauldron
# 64                   /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_sqa_cauldron
# 65               /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_wikisql_cauldron
# 66                /data/weka/ellisb/datasets/video/llava_ov_data/images/screen2words_cauldron
# 67                      /data/weka/ellisb/datasets/video/llava_ov_data/images/tabmwp_cauldron
# 68        /data/weka/ellisb/datasets/video/llava_ov_data/images/tallyqa_cauldron_llava_format
# 69         /data/weka/ellisb/datasets/video/llava_ov_data/images/st_vqa_cauldron_llava_format
# 70            /data/weka/ellisb/datasets/video/llava_ov_data/images/tqa_cauldron_llava_format
# 71       /data/weka/ellisb/datasets/video/llava_ov_data/images/visual7w_cauldron_llava_format
# 72                   /data/weka/ellisb/datasets/video/llava_ov_data/images/visualmrc_cauldron
# 73         /data/weka/ellisb/datasets/video/llava_ov_data/images/vqarad_cauldron_llava_format
# 74            /data/weka/ellisb/datasets/video/llava_ov_data/images/vsr_cauldron_llava_format
# 75                     /data/weka/ellisb/datasets/video/llava_ov_data/images/vistext_cauldron
# 76                    /data/weka/ellisb/datasets/video/llava_ov_data/images/websight_cauldron
# 77                                                                                        NaN
# 78                                                                                        NaN
# 79                                                                                        NaN
# 80                                                                                        NaN
# 81                                                                                        NaN
#
#    exists
# 0     NaN
# 1     NaN
# 2     NaN
# 3    True
# 4    True
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9    True
# 10   True
# 11   True
# 12   True
# 13   True
# 14   True
# 15   True
# 16   True
# 17   True
# 18   True
# 19    NaN
# 20   True
# 21   True
# 22    NaN
# 23   True
# 24   True
# 25   True
# 26   True
# 27   True
# 28   True
# 29   True
# 30   True
# 31   True
# 32   True
# 33   True
# 34   True
# 35   True
# 36   True
# 37   True
# 38   True
# 39   True
# 40    NaN
# 41   True
# 42   True
# 43   True
# 44    NaN
# 45   True
# 46   True
# 47    NaN
# 48    NaN
# 49   True
# 50   True
# 51   True
# 52   True
# 53   True
# 54   True
# 55   True
# 56   True
# 57   True
# 58   True
# 59   True
# 60   True
# 61   True
# 62   True
# 63   True
# 64   True
# 65   True
# 66   True
# 67   True
# 68   True
# 69   True
# 70   True
# 71   True
# 72   True
# 73   True
# 74   True
# 75   True
# 76   True
# 77    NaN
# 78    NaN
# 79    NaN
# 80    NaN
# 81    NaN

# %%
pd.set_option('display.max_rows', 100)
merged_df
# Out:
#                                                                                                               json_path  \
# 0            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_next_fit_mix_filtered_text_wild_738590.json
# 1                                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_wild_4v_39k.json
# 2                                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_wild_4v_12k.json
# 3                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_metagen_87358.json
# 4                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_rule_geo_100000.json
# 5   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/cambrian_filtered_gpt4vo_sp_token_fltd_max10k_checked.json
# 6                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/VisualWebInstruct_filtered_263589.json
# 7                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/visual_chat_en_26048_gpt4o_coco_checked.json
# 8                                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llavar_gpt4_20k.json
# 9               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_azuregpt_detailed_understanding_4874.json
# 10                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_vqa_4404.json
# 11                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_azuregpt4v_1992.json
# 12                                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_chart_1787.json
# 13                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_normal_gpt4v_filtered_10500.json
# 14                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_vflan4v_20000.json
# 15                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_laion4v_50000.json
# 16                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textocr_gpt4v_train_converted_25114.json
# 17                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_train_internvl_single_12413.json
# 18                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textcaps_train_21952.json
# 19                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_qa_sft.json
# 20                                             /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_cap_sft.json
# 21                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_ie_sft.json
# 22                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_kg_sft.json
# 23                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/vision_flan_filtered_186070.json
# 24                                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mathqa_29837.json
# 25                                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo3k_2101.json
# 26                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_qa_converted_67833.json
# 27                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_align_converted_60252.json
# 28                                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4o_dataset.jsonl
# 29                                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-coco-50k.json
# 30                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-knowledge-2k.json
# 31                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-llava-30k.json
# 32                                     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-sam-20k.json
# 33                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_CLEVR-Math_5290.json
# 34                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_FigureQA_17597.json
# 35                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Geometry3K_9734.json
# 36                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GeoQA+_17172.json
# 37                                     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GEOS_508.json
# 38                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_IconQA_22599.json
# 39                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_MapQA_5235.json
# 40                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PlotQA_5485.json
# 41                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PMC-VQA_35958.json
# 42                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Super-CLEVR_8652.json
# 43                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TabMWP_22462.json
# 44                                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TQA_10181.json
# 45                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_UniGeo_11959.json
# 46                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VizWiz_6614.json
# 47                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VQA-AS_5907.json
# 48                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VQA-RAD_2130.json
# 49    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_qwen2_72b_st_300000_sp_token_fltd_299992.json
# 50                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_st_300000.json
# 51       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_mt_300000_sp_token_fltd_299998.json
# 52                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/image_textualization_dataset_filtered.json
# 53                                         /mnt/bn/vl-research/data/llava_instruct/cauldron/ai2d_llava_format_2434.json
# 54                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/chart2text_26961.json
# 55                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/chartqa_18265_llava_format.json
# 56                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/diagram_image_to_text_300.json
# 57                                /mnt/bn/vl-research/data/llava_instruct/cauldron/hateful_memes_8500_llava_format.json
# 58                                        /mnt/bn/vl-research/data/llava_instruct/cauldron/hitab_2500_llava_format.json
# 59                                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/iam_5663.json
# 60                              /mnt/bn/vl-research/data/llava_instruct/cauldron/infographic_vqa_2118_llava_format.json
# 61                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/intergps_1280_llava_format.json
# 62                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/mapqa_37417_llava_format.json
# 63                                            /mnt/bn/vl-research/data/llava_instruct/cauldron/rendered_text_10000.json
# 64                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_sqa_8514.json
# 65                                            /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wikisql_74989.json
# 66                                             /mnt/bn/vl-research/data/llava_instruct/cauldron/screen2words_15730.json
# 67                                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/tabmwp_22722.json
# 68                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/tallyqa_98680_llava_format.json
# 69                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/st_vqa_17247_llava_format.json
# 70                                         /mnt/bn/vl-research/data/llava_instruct/cauldron/tqa_llava_format_27307.json
# 71                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/visual7w_llava_format_14366.json
# 72                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/visualmrc_3027.json
# 73                                        /mnt/bn/vl-research/data/llava_instruct/cauldron/vqarad_313_llava_format.json
# 74                                          /mnt/bn/vl-research/data/llava_instruct/cauldron/vsr_2157_llava_format.json
# 75                                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/vistext_9969.json
# 76                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/websight_10000.json
# 77                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_ofa_DEMON-FULL_filtered_311085.json
# 78                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_ofa_mantis-instruct_reformatted.json
# 79                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/academic_source_30s_v1_all.json
# 80                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/0718_0_30_s_academic_mc_v0_1_all.json
# 81                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4video_255000.json
#
#    sampling_strategy                           short_names  \
# 0          first:50%                                   NaN
# 1          first:10%                                   NaN
# 2          first:10%                                   NaN
# 3          first:10%                    mavis_math_metagen
# 4          first:10%                   mavis_math_rule_geo
# 5                all                                   NaN
# 6                all                                   NaN
# 7                all                                   NaN
# 8          first:10%                                   NaN
# 9                all                           ai2d(gpt4v)
# 10               all                       infographic_vqa
# 11               all                    infographic(gpt4v)
# 12               all                             lrv_chart
# 13         first:10%                  lrv_normal(filtered)
# 14         first:30%               allava_instruct_vflan4v
# 15         first:30%               allava_instruct_laion4v
# 16         first:10%                        textocr(gpt4v)
# 17         first:10%                        ai2d(internvl)
# 18         first:10%                              textcaps
# 19         first:10%                                   NaN
# 20         first:10%                           ureader_cap
# 21         first:10%                            ureader_ie
# 22         first:10%                                   NaN
# 23               all                 vision_flan(filtered)
# 24               all                                mathqa
# 25               all                                 geo3k
# 26         first:10%                           geo170k(qa)
# 27         first:10%                        geo170k(align)
# 28               all                            sharegpt4o
# 29               all                      sharegpt4v(coco)
# 30               all                 sharegpt4v(knowledge)
# 31               all                     sharegpt4v(llava)
# 32               all                       sharegpt4v(sam)
# 33         first:10%                 CLEVR-Math(MathV360K)
# 34         first:10%                   FigureQA(MathV360K)
# 35         first:10%                 Geometry3K(MathV360K)
# 36         first:10%                     GeoQA+(MathV360K)
# 37               all                       GEOS(MathV360K)
# 38          first:5%                     IconQA(MathV360K)
# 39         first:10%                      MapQA(MathV360K)
# 40         first:10%                                   NaN
# 41          first:1%                    PMC-VQA(MathV360K)
# 42         first:10%                Super-CLEVR(MathV360K)
# 43         first:10%                     TabMWP(MathV360K)
# 44         first:10%                                   NaN
# 45         first:10%                     UniGeo(MathV360K)
# 46         first:10%                     VizWiz(MathV360K)
# 47         first:10%                                   NaN
# 48         first:10%                                   NaN
# 49           end:20%              magpie_pro(qwen2_72b_st)
# 50           end:20%                 magpie_pro(l3_80b_st)
# 51           end:20%                 magpie_pro(l3_80b_mt)
# 52         first:20%        image_textualization(filtered)
# 53               all           ai2d(cauldron,llava_format)
# 54         first:10%                  chart2text(cauldron)
# 55         first:10%        chartqa(cauldron,llava_format)
# 56               all       diagram_image_to_text(cauldron)
# 57         first:10%  hateful_memes(cauldron,llava_format)
# 58         first:10%          hitab(cauldron,llava_format)
# 59         first:10%                         iam(cauldron)
# 60         first:10%          infographic_vqa_llava_format
# 61         first:10%       intergps(cauldron,llava_format)
# 62         first:10%          mapqa(cauldron,llava_format)
# 63         first:10%               rendered_text(cauldron)
# 64         first:10%                   robut_sqa(cauldron)
# 65         first:10%               robut_wikisql(cauldron)
# 66         first:10%                screen2words(cauldron)
# 67          first:5%                      tabmwp(cauldron)
# 68          first:5%        tallyqa(cauldron,llava_format)
# 69         first:10%         st_vqa(cauldron,llava_format)
# 70          first:5%            tqa(cauldron,llava_format)
# 71         first:10%       visual7w(cauldron,llava_format)
# 72         first:10%                   visualmrc(cauldron)
# 73         first:10%         vqarad(cauldron,llava_format)
# 74         first:10%            vsr(cauldron,llava_format)
# 75         first:10%                     vistext(cauldron)
# 76         first:10%                    websight(cauldron)
# 77               all                                   NaN
# 78               all                                   NaN
# 79               all                                   NaN
# 80               all                                   NaN
# 81               all                                   NaN
#
#                             clean_names  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                    mavis_math_metagen
# 4                   mavis_math_rule_geo
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                            ai2d_gpt4v
# 10                      infographic_vqa
# 11                    infographic_gpt4v
# 12                            lrv_chart
# 13                  lrv_normal_filtered
# 14              allava_instruct_vflan4v
# 15              allava_instruct_laion4v
# 16                        textocr_gpt4v
# 17                        ai2d_internvl
# 18                             textcaps
# 19                                  NaN
# 20                          ureader_cap
# 21                           ureader_ie
# 22                                  NaN
# 23                 vision_flan_filtered
# 24                               mathqa
# 25                                geo3k
# 26                           geo170k_qa
# 27                        geo170k_align
# 28                           sharegpt4o
# 29                      sharegpt4v_coco
# 30                 sharegpt4v_knowledge
# 31                     sharegpt4v_llava
# 32                       sharegpt4v_sam
# 33                 CLEVR_Math_MathV360K
# 34                   FigureQA_MathV360K
# 35                 Geometry3K_MathV360K
# 36                     GeoQA__MathV360K
# 37                       GEOS_MathV360K
# 38                     IconQA_MathV360K
# 39                      MapQA_MathV360K
# 40                                  NaN
# 41                    PMC_VQA_MathV360K
# 42                Super_CLEVR_MathV360K
# 43                     TabMWP_MathV360K
# 44                                  NaN
# 45                     UniGeo_MathV360K
# 46                     VizWiz_MathV360K
# 47                                  NaN
# 48                                  NaN
# 49              magpie_pro_qwen2_72b_st
# 50                 magpie_pro_l3_80b_st
# 51                 magpie_pro_l3_80b_mt
# 52        image_textualization_filtered
# 53           ai2d_cauldron_llava_format
# 54                  chart2text_cauldron
# 55        chartqa_cauldron_llava_format
# 56       diagram_image_to_text_cauldron
# 57  hateful_memes_cauldron_llava_format
# 58          hitab_cauldron_llava_format
# 59                         iam_cauldron
# 60         infographic_vqa_llava_format
# 61       intergps_cauldron_llava_format
# 62          mapqa_cauldron_llava_format
# 63               rendered_text_cauldron
# 64                   robut_sqa_cauldron
# 65               robut_wikisql_cauldron
# 66                screen2words_cauldron
# 67                      tabmwp_cauldron
# 68        tallyqa_cauldron_llava_format
# 69         st_vqa_cauldron_llava_format
# 70            tqa_cauldron_llava_format
# 71       visual7w_cauldron_llava_format
# 72                   visualmrc_cauldron
# 73         vqarad_cauldron_llava_format
# 74            vsr_cauldron_llava_format
# 75                     vistext_cauldron
# 76                    websight_cauldron
# 77                                  NaN
# 78                                  NaN
# 79                                  NaN
# 80                                  NaN
# 81                                  NaN
#
#                                                                                       img_dir  \
# 0                                                                                         NaN
# 1                                                                                         NaN
# 2                                                                                         NaN
# 3                    /data/weka/ellisb/datasets/video/llava_ov_data/images/mavis_math_metagen
# 4                   /data/weka/ellisb/datasets/video/llava_ov_data/images/mavis_math_rule_geo
# 5                                                                                         NaN
# 6                                                                                         NaN
# 7                                                                                         NaN
# 8                                                                                         NaN
# 9                            /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_gpt4v
# 10                      /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_vqa
# 11                    /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_gpt4v
# 12                            /data/weka/ellisb/datasets/video/llava_ov_data/images/lrv_chart
# 13                  /data/weka/ellisb/datasets/video/llava_ov_data/images/lrv_normal_filtered
# 14              /data/weka/ellisb/datasets/video/llava_ov_data/images/allava_instruct_vflan4v
# 15              /data/weka/ellisb/datasets/video/llava_ov_data/images/allava_instruct_laion4v
# 16                        /data/weka/ellisb/datasets/video/llava_ov_data/images/textocr_gpt4v
# 17                        /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_internvl
# 18                             /data/weka/ellisb/datasets/video/llava_ov_data/images/textcaps
# 19                                                                                        NaN
# 20                          /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_cap
# 21                           /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_ie
# 22                                                                                        NaN
# 23                 /data/weka/ellisb/datasets/video/llava_ov_data/images/vision_flan_filtered
# 24                               /data/weka/ellisb/datasets/video/llava_ov_data/images/mathqa
# 25                                /data/weka/ellisb/datasets/video/llava_ov_data/images/geo3k
# 26                           /data/weka/ellisb/datasets/video/llava_ov_data/images/geo170k_qa
# 27                        /data/weka/ellisb/datasets/video/llava_ov_data/images/geo170k_align
# 28                           /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4o
# 29                      /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_coco
# 30                 /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_knowledge
# 31                     /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_llava
# 32                       /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_sam
# 33                 /data/weka/ellisb/datasets/video/llava_ov_data/images/CLEVR_Math_MathV360K
# 34                   /data/weka/ellisb/datasets/video/llava_ov_data/images/FigureQA_MathV360K
# 35                 /data/weka/ellisb/datasets/video/llava_ov_data/images/Geometry3K_MathV360K
# 36                     /data/weka/ellisb/datasets/video/llava_ov_data/images/GeoQA__MathV360K
# 37                       /data/weka/ellisb/datasets/video/llava_ov_data/images/GEOS_MathV360K
# 38                     /data/weka/ellisb/datasets/video/llava_ov_data/images/IconQA_MathV360K
# 39                      /data/weka/ellisb/datasets/video/llava_ov_data/images/MapQA_MathV360K
# 40                                                                                        NaN
# 41                    /data/weka/ellisb/datasets/video/llava_ov_data/images/PMC_VQA_MathV360K
# 42                /data/weka/ellisb/datasets/video/llava_ov_data/images/Super_CLEVR_MathV360K
# 43                     /data/weka/ellisb/datasets/video/llava_ov_data/images/TabMWP_MathV360K
# 44                                                                                        NaN
# 45                     /data/weka/ellisb/datasets/video/llava_ov_data/images/UniGeo_MathV360K
# 46                     /data/weka/ellisb/datasets/video/llava_ov_data/images/VizWiz_MathV360K
# 47                                                                                        NaN
# 48                                                                                        NaN
# 49              /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_qwen2_72b_st
# 50                 /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_l3_80b_st
# 51                 /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_l3_80b_mt
# 52        /data/weka/ellisb/datasets/video/llava_ov_data/images/image_textualization_filtered
# 53           /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_cauldron_llava_format
# 54                  /data/weka/ellisb/datasets/video/llava_ov_data/images/chart2text_cauldron
# 55        /data/weka/ellisb/datasets/video/llava_ov_data/images/chartqa_cauldron_llava_format
# 56       /data/weka/ellisb/datasets/video/llava_ov_data/images/diagram_image_to_text_cauldron
# 57  /data/weka/ellisb/datasets/video/llava_ov_data/images/hateful_memes_cauldron_llava_format
# 58          /data/weka/ellisb/datasets/video/llava_ov_data/images/hitab_cauldron_llava_format
# 59                         /data/weka/ellisb/datasets/video/llava_ov_data/images/iam_cauldron
# 60         /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_vqa_llava_format
# 61       /data/weka/ellisb/datasets/video/llava_ov_data/images/intergps_cauldron_llava_format
# 62          /data/weka/ellisb/datasets/video/llava_ov_data/images/mapqa_cauldron_llava_format
# 63               /data/weka/ellisb/datasets/video/llava_ov_data/images/rendered_text_cauldron
# 64                   /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_sqa_cauldron
# 65               /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_wikisql_cauldron
# 66                /data/weka/ellisb/datasets/video/llava_ov_data/images/screen2words_cauldron
# 67                      /data/weka/ellisb/datasets/video/llava_ov_data/images/tabmwp_cauldron
# 68        /data/weka/ellisb/datasets/video/llava_ov_data/images/tallyqa_cauldron_llava_format
# 69         /data/weka/ellisb/datasets/video/llava_ov_data/images/st_vqa_cauldron_llava_format
# 70            /data/weka/ellisb/datasets/video/llava_ov_data/images/tqa_cauldron_llava_format
# 71       /data/weka/ellisb/datasets/video/llava_ov_data/images/visual7w_cauldron_llava_format
# 72                   /data/weka/ellisb/datasets/video/llava_ov_data/images/visualmrc_cauldron
# 73         /data/weka/ellisb/datasets/video/llava_ov_data/images/vqarad_cauldron_llava_format
# 74            /data/weka/ellisb/datasets/video/llava_ov_data/images/vsr_cauldron_llava_format
# 75                     /data/weka/ellisb/datasets/video/llava_ov_data/images/vistext_cauldron
# 76                    /data/weka/ellisb/datasets/video/llava_ov_data/images/websight_cauldron
# 77                                                                                        NaN
# 78                                                                                        NaN
# 79                                                                                        NaN
# 80                                                                                        NaN
# 81                                                                                        NaN
#
#    exists
# 0     NaN
# 1     NaN
# 2     NaN
# 3    True
# 4    True
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9    True
# 10   True
# 11   True
# 12   True
# 13   True
# 14   True
# 15   True
# 16   True
# 17   True
# 18   True
# 19    NaN
# 20   True
# 21   True
# 22    NaN
# 23   True
# 24   True
# 25   True
# 26   True
# 27   True
# 28   True
# 29   True
# 30   True
# 31   True
# 32   True
# 33   True
# 34   True
# 35   True
# 36   True
# 37   True
# 38   True
# 39   True
# 40    NaN
# 41   True
# 42   True
# 43   True
# 44    NaN
# 45   True
# 46   True
# 47    NaN
# 48    NaN
# 49   True
# 50   True
# 51   True
# 52   True
# 53   True
# 54   True
# 55   True
# 56   True
# 57   True
# 58   True
# 59   True
# 60   True
# 61   True
# 62   True
# 63   True
# 64   True
# 65   True
# 66   True
# 67   True
# 68   True
# 69   True
# 70   True
# 71   True
# 72   True
# 73   True
# 74   True
# 75   True
# 76   True
# 77    NaN
# 78    NaN
# 79    NaN
# 80    NaN
# 81    NaN

# %% [markdown]
# ### all dataset entries not found in ov data yaml

# %%
a = ov_df.merge(df2, how="right", on="json_path")
a[a["sampling_strategy"].isna()]
# Out:
#                                                                                      json_path  \
# 2      /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/k12_printing_train_256646.json
# 3        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/iiit5k_annotations_2000.json
# 4      /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/hme100k_train_clean_74502.json
# 10  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/scienceqa_nona_context_19218.json
# 45             /mnt/bn/vl-research/data/llava_instruct/cauldron/aokvqa_16539_llava_format.json
# 48              /mnt/bn/vl-research/data/llava_instruct/cauldron/clevr_70000_llava_format.json
# 50              /mnt/bn/vl-research/data/llava_instruct/cauldron/dvqa_200000_llava_format.json
# 51          /mnt/bn/vl-research/data/llava_instruct/cauldron/figureqa_100000_llava_format.json
# 52                        /mnt/bn/vl-research/data/llava_instruct/cauldron/geomverse_9303.json
# 56                           /mnt/bn/vl-research/data/llava_instruct/cauldron/raven_42000.json
# 57             /mnt/bn/vl-research/data/llava_instruct/cauldron/iconqa_llava_format_27307.json
# 61                      /mnt/bn/vl-research/data/llava_instruct/cauldron/multihiertt_7619.json
# 65          /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wtq_38246_llava_format.json
# 67           /mnt/bn/vl-research/data/llava_instruct/cauldron/scienceqa_llava_format_4976.json
#
#    sampling_strategy                       short_names  \
# 2                NaN                      k12_printing
# 3                NaN                            iiit5k
# 4                NaN                           hme100k
# 10               NaN           scienceqa(nona_context)
# 45               NaN     aokvqa(cauldron,llava_format)
# 48               NaN      clevr(cauldron,llava_format)
# 50               NaN       dvqa(cauldron,llava_format)
# 51               NaN   figureqa(cauldron,llava_format)
# 52               NaN               geomverse(cauldron)
# 56               NaN                   raven(cauldron)
# 57               NaN     iconqa(cauldron,llava_format)
# 61               NaN             multihiertt(cauldron)
# 65               NaN  robut_wtq(cauldron,llava_format)
# 67               NaN  scienceqa(cauldron,llava_format)
#
#                         clean_names  \
# 2                      k12_printing
# 3                            iiit5k
# 4                           hme100k
# 10           scienceqa_nona_context
# 45     aokvqa_cauldron_llava_format
# 48      clevr_cauldron_llava_format
# 50       dvqa_cauldron_llava_format
# 51   figureqa_cauldron_llava_format
# 52               geomverse_cauldron
# 56                   raven_cauldron
# 57     iconqa_cauldron_llava_format
# 61             multihiertt_cauldron
# 65  robut_wtq_cauldron_llava_format
# 67  scienceqa_cauldron_llava_format
#
#                                                                                   img_dir  \
# 2                      /data/weka/ellisb/datasets/video/llava_ov_data/images/k12_printing
# 3                            /data/weka/ellisb/datasets/video/llava_ov_data/images/iiit5k
# 4                           /data/weka/ellisb/datasets/video/llava_ov_data/images/hme100k
# 10           /data/weka/ellisb/datasets/video/llava_ov_data/images/scienceqa_nona_context
# 45     /data/weka/ellisb/datasets/video/llava_ov_data/images/aokvqa_cauldron_llava_format
# 48      /data/weka/ellisb/datasets/video/llava_ov_data/images/clevr_cauldron_llava_format
# 50       /data/weka/ellisb/datasets/video/llava_ov_data/images/dvqa_cauldron_llava_format
# 51   /data/weka/ellisb/datasets/video/llava_ov_data/images/figureqa_cauldron_llava_format
# 52               /data/weka/ellisb/datasets/video/llava_ov_data/images/geomverse_cauldron
# 56                   /data/weka/ellisb/datasets/video/llava_ov_data/images/raven_cauldron
# 57     /data/weka/ellisb/datasets/video/llava_ov_data/images/iconqa_cauldron_llava_format
# 61             /data/weka/ellisb/datasets/video/llava_ov_data/images/multihiertt_cauldron
# 65  /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_wtq_cauldron_llava_format
# 67  /data/weka/ellisb/datasets/video/llava_ov_data/images/scienceqa_cauldron_llava_format
#
#     exists
# 2     True
# 3     True
# 4     True
# 10    True
# 45    True
# 48    True
# 50    True
# 51    True
# 52    True
# 56    True
# 57    True
# 61    True
# 65    True
# 67    True

# %% [markdown]
# ### all entries in ov yaml not found in their dataset

# %%
pd.set_option('display.max_colwidth', 120)
merged_df[merged_df["exists"] != True]
# Out:
#                                                                                                               json_path  \
# 0            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_next_fit_mix_filtered_text_wild_738590.json
# 1                                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_wild_4v_39k.json
# 2                                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_wild_4v_12k.json
# 5   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/cambrian_filtered_gpt4vo_sp_token_fltd_max10k_checked.json
# 6                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/VisualWebInstruct_filtered_263589.json
# 7                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/visual_chat_en_26048_gpt4o_coco_checked.json
# 8                                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llavar_gpt4_20k.json
# 19                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_qa_sft.json
# 22                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_kg_sft.json
# 40                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PlotQA_5485.json
# 44                                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TQA_10181.json
# 47                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VQA-AS_5907.json
# 48                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VQA-RAD_2130.json
# 77                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_ofa_DEMON-FULL_filtered_311085.json
# 78                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_ofa_mantis-instruct_reformatted.json
# 79                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/academic_source_30s_v1_all.json
# 80                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/0718_0_30_s_academic_mc_v0_1_all.json
# 81                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4video_255000.json
#
#    sampling_strategy short_names clean_names img_dir exists
# 0          first:50%         NaN         NaN     NaN    NaN
# 1          first:10%         NaN         NaN     NaN    NaN
# 2          first:10%         NaN         NaN     NaN    NaN
# 5                all         NaN         NaN     NaN    NaN
# 6                all         NaN         NaN     NaN    NaN
# 7                all         NaN         NaN     NaN    NaN
# 8          first:10%         NaN         NaN     NaN    NaN
# 19         first:10%         NaN         NaN     NaN    NaN
# 22         first:10%         NaN         NaN     NaN    NaN
# 40         first:10%         NaN         NaN     NaN    NaN
# 44         first:10%         NaN         NaN     NaN    NaN
# 47         first:10%         NaN         NaN     NaN    NaN
# 48         first:10%         NaN         NaN     NaN    NaN
# 77               all         NaN         NaN     NaN    NaN
# 78               all         NaN         NaN     NaN    NaN
# 79               all         NaN         NaN     NaN    NaN
# 80               all         NaN         NaN     NaN    NaN
# 81               all         NaN         NaN     NaN    NaN

# %%
manual_maps = {
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/academic_source_30s_v1_all.json": "/data/weka/ellisb/datasets/video/llava_video_178k/0_30_s_academic_v0_1/0_30_s_academic_oe_v0_1_qa_processed.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/0718_0_30_s_academic_mc_v0_1_all.json": "/data/weka/ellisb/datasets/video/llava_video_178k/0_30_s_academic_v0_1/0_30_s_academic_mc_v0_1_qa_processed.json",
    "/mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4video_255000.json": "/data/weka/ellisb/datasets/video/llava_video_178k/llava_hound/sharegptvideo_qa_255k_processed.json",
}

to_add = [
    # adding this here rather than combining the jsons
    {"img_dir": "/data/weka/ellisb/datasets/video/llava_video_178k/0_30_s_academic_v0_1/0_30_s_academic_v0_1_cap_processed.json", "sampling_strategy": "all"},
]

# Convert the list of dictionaries to a DataFrame and concatenate it with merged_df
merged_df = pd.concat([merged_df, pd.DataFrame(to_add)], ignore_index=True)

# apply manual mappings
for k, v in manual_maps.items():
    merged_df.loc[merged_df["json_path"] == k, "img_dir"] = v

# reapply the exists column
merged_df["exists"] = merged_df["img_dir"].apply(lambda x: os.path.exists(x) if x is not None and isinstance(x, str) else False)
merged_df[merged_df["exists"] != True]
# Out:
#                                                                                                               json_path  \
# 0            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_next_fit_mix_filtered_text_wild_738590.json
# 1                                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_wild_4v_39k.json
# 2                                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_wild_4v_12k.json
# 5   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/cambrian_filtered_gpt4vo_sp_token_fltd_max10k_checked.json
# 6                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/VisualWebInstruct_filtered_263589.json
# 7                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/visual_chat_en_26048_gpt4o_coco_checked.json
# 8                                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llavar_gpt4_20k.json
# 19                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_qa_sft.json
# 22                                              /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_kg_sft.json
# 40                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PlotQA_5485.json
# 44                                    /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TQA_10181.json
# 47                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VQA-AS_5907.json
# 48                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VQA-RAD_2130.json
# 77                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_ofa_DEMON-FULL_filtered_311085.json
# 78                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/llava_ofa_mantis-instruct_reformatted.json
#
#    sampling_strategy short_names clean_names img_dir  exists
# 0          first:50%         NaN         NaN     NaN   False
# 1          first:10%         NaN         NaN     NaN   False
# 2          first:10%         NaN         NaN     NaN   False
# 5                all         NaN         NaN     NaN   False
# 6                all         NaN         NaN     NaN   False
# 7                all         NaN         NaN     NaN   False
# 8          first:10%         NaN         NaN     NaN   False
# 19         first:10%         NaN         NaN     NaN   False
# 22         first:10%         NaN         NaN     NaN   False
# 40         first:10%         NaN         NaN     NaN   False
# 44         first:10%         NaN         NaN     NaN   False
# 47         first:10%         NaN         NaN     NaN   False
# 48         first:10%         NaN         NaN     NaN   False
# 77               all         NaN         NaN     NaN   False
# 78               all         NaN         NaN     NaN   False

# %% [markdown]
# # save the clean data to a new yaml file

# %%
clean_data = merged_df[merged_df["exists"]].copy()
clean_data["llava_json_path"] = clean_data["json_path"]
clean_data["json_path"] = clean_data["img_dir"]
clean_data = clean_data.drop(columns=["short_names", "clean_names", "img_dir", "exists"])
clean_data
# Out:
#                                                                                                            json_path  \
# 3                                           /data/weka/ellisb/datasets/video/llava_ov_data/images/mavis_math_metagen
# 4                                          /data/weka/ellisb/datasets/video/llava_ov_data/images/mavis_math_rule_geo
# 9                                                   /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_gpt4v
# 10                                             /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_vqa
# 11                                           /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_gpt4v
# 12                                                   /data/weka/ellisb/datasets/video/llava_ov_data/images/lrv_chart
# 13                                         /data/weka/ellisb/datasets/video/llava_ov_data/images/lrv_normal_filtered
# 14                                     /data/weka/ellisb/datasets/video/llava_ov_data/images/allava_instruct_vflan4v
# 15                                     /data/weka/ellisb/datasets/video/llava_ov_data/images/allava_instruct_laion4v
# 16                                               /data/weka/ellisb/datasets/video/llava_ov_data/images/textocr_gpt4v
# 17                                               /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_internvl
# 18                                                    /data/weka/ellisb/datasets/video/llava_ov_data/images/textcaps
# 20                                                 /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_cap
# 21                                                  /data/weka/ellisb/datasets/video/llava_ov_data/images/ureader_ie
# 23                                        /data/weka/ellisb/datasets/video/llava_ov_data/images/vision_flan_filtered
# 24                                                      /data/weka/ellisb/datasets/video/llava_ov_data/images/mathqa
# 25                                                       /data/weka/ellisb/datasets/video/llava_ov_data/images/geo3k
# 26                                                  /data/weka/ellisb/datasets/video/llava_ov_data/images/geo170k_qa
# 27                                               /data/weka/ellisb/datasets/video/llava_ov_data/images/geo170k_align
# 28                                                  /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4o
# 29                                             /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_coco
# 30                                        /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_knowledge
# 31                                            /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_llava
# 32                                              /data/weka/ellisb/datasets/video/llava_ov_data/images/sharegpt4v_sam
# 33                                        /data/weka/ellisb/datasets/video/llava_ov_data/images/CLEVR_Math_MathV360K
# 34                                          /data/weka/ellisb/datasets/video/llava_ov_data/images/FigureQA_MathV360K
# 35                                        /data/weka/ellisb/datasets/video/llava_ov_data/images/Geometry3K_MathV360K
# 36                                            /data/weka/ellisb/datasets/video/llava_ov_data/images/GeoQA__MathV360K
# 37                                              /data/weka/ellisb/datasets/video/llava_ov_data/images/GEOS_MathV360K
# 38                                            /data/weka/ellisb/datasets/video/llava_ov_data/images/IconQA_MathV360K
# 39                                             /data/weka/ellisb/datasets/video/llava_ov_data/images/MapQA_MathV360K
# 41                                           /data/weka/ellisb/datasets/video/llava_ov_data/images/PMC_VQA_MathV360K
# 42                                       /data/weka/ellisb/datasets/video/llava_ov_data/images/Super_CLEVR_MathV360K
# 43                                            /data/weka/ellisb/datasets/video/llava_ov_data/images/TabMWP_MathV360K
# 45                                            /data/weka/ellisb/datasets/video/llava_ov_data/images/UniGeo_MathV360K
# 46                                            /data/weka/ellisb/datasets/video/llava_ov_data/images/VizWiz_MathV360K
# 49                                     /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_qwen2_72b_st
# 50                                        /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_l3_80b_st
# 51                                        /data/weka/ellisb/datasets/video/llava_ov_data/images/magpie_pro_l3_80b_mt
# 52                               /data/weka/ellisb/datasets/video/llava_ov_data/images/image_textualization_filtered
# 53                                  /data/weka/ellisb/datasets/video/llava_ov_data/images/ai2d_cauldron_llava_format
# 54                                         /data/weka/ellisb/datasets/video/llava_ov_data/images/chart2text_cauldron
# 55                               /data/weka/ellisb/datasets/video/llava_ov_data/images/chartqa_cauldron_llava_format
# 56                              /data/weka/ellisb/datasets/video/llava_ov_data/images/diagram_image_to_text_cauldron
# 57                         /data/weka/ellisb/datasets/video/llava_ov_data/images/hateful_memes_cauldron_llava_format
# 58                                 /data/weka/ellisb/datasets/video/llava_ov_data/images/hitab_cauldron_llava_format
# 59                                                /data/weka/ellisb/datasets/video/llava_ov_data/images/iam_cauldron
# 60                                /data/weka/ellisb/datasets/video/llava_ov_data/images/infographic_vqa_llava_format
# 61                              /data/weka/ellisb/datasets/video/llava_ov_data/images/intergps_cauldron_llava_format
# 62                                 /data/weka/ellisb/datasets/video/llava_ov_data/images/mapqa_cauldron_llava_format
# 63                                      /data/weka/ellisb/datasets/video/llava_ov_data/images/rendered_text_cauldron
# 64                                          /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_sqa_cauldron
# 65                                      /data/weka/ellisb/datasets/video/llava_ov_data/images/robut_wikisql_cauldron
# 66                                       /data/weka/ellisb/datasets/video/llava_ov_data/images/screen2words_cauldron
# 67                                             /data/weka/ellisb/datasets/video/llava_ov_data/images/tabmwp_cauldron
# 68                               /data/weka/ellisb/datasets/video/llava_ov_data/images/tallyqa_cauldron_llava_format
# 69                                /data/weka/ellisb/datasets/video/llava_ov_data/images/st_vqa_cauldron_llava_format
# 70                                   /data/weka/ellisb/datasets/video/llava_ov_data/images/tqa_cauldron_llava_format
# 71                              /data/weka/ellisb/datasets/video/llava_ov_data/images/visual7w_cauldron_llava_format
# 72                                          /data/weka/ellisb/datasets/video/llava_ov_data/images/visualmrc_cauldron
# 73                                /data/weka/ellisb/datasets/video/llava_ov_data/images/vqarad_cauldron_llava_format
# 74                                   /data/weka/ellisb/datasets/video/llava_ov_data/images/vsr_cauldron_llava_format
# 75                                            /data/weka/ellisb/datasets/video/llava_ov_data/images/vistext_cauldron
# 76                                           /data/weka/ellisb/datasets/video/llava_ov_data/images/websight_cauldron
# 79  /data/weka/ellisb/datasets/video/llava_video_178k/0_30_s_academic_v0_1/0_30_s_academic_oe_v0_1_qa_processed.json
# 80  /data/weka/ellisb/datasets/video/llava_video_178k/0_30_s_academic_v0_1/0_30_s_academic_mc_v0_1_qa_processed.json
# 81                /data/weka/ellisb/datasets/video/llava_video_178k/llava_hound/sharegptvideo_qa_255k_processed.json
# 82    /data/weka/ellisb/datasets/video/llava_video_178k/0_30_s_academic_v0_1/0_30_s_academic_v0_1_cap_processed.json
#
#    sampling_strategy  \
# 3          first:10%
# 4          first:10%
# 9                all
# 10               all
# 11               all
# 12               all
# 13         first:10%
# 14         first:30%
# 15         first:30%
# 16         first:10%
# 17         first:10%
# 18         first:10%
# 20         first:10%
# 21         first:10%
# 23               all
# 24               all
# 25               all
# 26         first:10%
# 27         first:10%
# 28               all
# 29               all
# 30               all
# 31               all
# 32               all
# 33         first:10%
# 34         first:10%
# 35         first:10%
# 36         first:10%
# 37               all
# 38          first:5%
# 39         first:10%
# 41          first:1%
# 42         first:10%
# 43         first:10%
# 45         first:10%
# 46         first:10%
# 49           end:20%
# 50           end:20%
# 51           end:20%
# 52         first:20%
# 53               all
# 54         first:10%
# 55         first:10%
# 56               all
# 57         first:10%
# 58         first:10%
# 59         first:10%
# 60         first:10%
# 61         first:10%
# 62         first:10%
# 63         first:10%
# 64         first:10%
# 65         first:10%
# 66         first:10%
# 67          first:5%
# 68          first:5%
# 69         first:10%
# 70          first:5%
# 71         first:10%
# 72         first:10%
# 73         first:10%
# 74         first:10%
# 75         first:10%
# 76         first:10%
# 79               all
# 80               all
# 81               all
# 82               all
#
#                                                                                                       llava_json_path
# 3                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_metagen_87358.json
# 4                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mavis_math_rule_geo_100000.json
# 9             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_azuregpt_detailed_understanding_4874.json
# 10                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_vqa_4404.json
# 11                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/infographic_azuregpt4v_1992.json
# 12                                       /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_chart_1787.json
# 13                      /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/lrv_normal_gpt4v_filtered_10500.json
# 14                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_vflan4v_20000.json
# 15                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/allava_instruct_laion4v_50000.json
# 16                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textocr_gpt4v_train_converted_25114.json
# 17                     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/ai2d_train_internvl_single_12413.json
# 18                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/textcaps_train_21952.json
# 20                                           /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_cap_sft.json
# 21                                            /mnt/bn/vl-research/data/llava_instruct/ureader_new/ureader_ie_sft.json
# 23                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/vision_flan_filtered_186070.json
# 24                                         /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/mathqa_29837.json
# 25                                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo3k_2101.json
# 26                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_qa_converted_67833.json
# 27                        /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/geo170k_align_converted_60252.json
# 28                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4o_dataset.jsonl
# 29                                  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-coco-50k.json
# 30                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-knowledge-2k.json
# 31                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-llava-30k.json
# 32                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4v-sam-20k.json
# 33                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_CLEVR-Math_5290.json
# 34                             /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_FigureQA_17597.json
# 35                            /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Geometry3K_9734.json
# 36                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GeoQA+_17172.json
# 37                                   /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_GEOS_508.json
# 38                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_IconQA_22599.json
# 39                                 /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_MapQA_5235.json
# 41                              /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_PMC-VQA_35958.json
# 42                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_Super-CLEVR_8652.json
# 43                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_TabMWP_22462.json
# 45                               /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_UniGeo_11959.json
# 46                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/MathV360K_VizWiz_6614.json
# 49  /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_qwen2_72b_st_300000_sp_token_fltd_299992.json
# 50                          /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_st_300000.json
# 51     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/magpie_pro_l3_80b_mt_300000_sp_token_fltd_299998.json
# 52                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/image_textualization_dataset_filtered.json
# 53                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/ai2d_llava_format_2434.json
# 54                                             /mnt/bn/vl-research/data/llava_instruct/cauldron/chart2text_26961.json
# 55                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/chartqa_18265_llava_format.json
# 56                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/diagram_image_to_text_300.json
# 57                              /mnt/bn/vl-research/data/llava_instruct/cauldron/hateful_memes_8500_llava_format.json
# 58                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/hitab_2500_llava_format.json
# 59                                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/iam_5663.json
# 60                            /mnt/bn/vl-research/data/llava_instruct/cauldron/infographic_vqa_2118_llava_format.json
# 61                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/intergps_1280_llava_format.json
# 62                                     /mnt/bn/vl-research/data/llava_instruct/cauldron/mapqa_37417_llava_format.json
# 63                                          /mnt/bn/vl-research/data/llava_instruct/cauldron/rendered_text_10000.json
# 64                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_sqa_8514.json
# 65                                          /mnt/bn/vl-research/data/llava_instruct/cauldron/robut_wikisql_74989.json
# 66                                           /mnt/bn/vl-research/data/llava_instruct/cauldron/screen2words_15730.json
# 67                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/tabmwp_22722.json
# 68                                   /mnt/bn/vl-research/data/llava_instruct/cauldron/tallyqa_98680_llava_format.json
# 69                                    /mnt/bn/vl-research/data/llava_instruct/cauldron/st_vqa_17247_llava_format.json
# 70                                       /mnt/bn/vl-research/data/llava_instruct/cauldron/tqa_llava_format_27307.json
# 71                                  /mnt/bn/vl-research/data/llava_instruct/cauldron/visual7w_llava_format_14366.json
# 72                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/visualmrc_3027.json
# 73                                      /mnt/bn/vl-research/data/llava_instruct/cauldron/vqarad_313_llava_format.json
# 74                                        /mnt/bn/vl-research/data/llava_instruct/cauldron/vsr_2157_llava_format.json
# 75                                                 /mnt/bn/vl-research/data/llava_instruct/cauldron/vistext_9969.json
# 76                                               /mnt/bn/vl-research/data/llava_instruct/cauldron/websight_10000.json
# 79                           /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/academic_source_30s_v1_all.json
# 80                     /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/0718_0_30_s_academic_mc_v0_1_all.json
# 81                                /mnt/bn/vl-research/data/llava_instruct/real_vision_flan/sharegpt4video_255000.json
# 82                                                                                                                NaN

# %%
with open("clean_ov_data.yaml", "w") as f:
    yaml.safe_dump({"datasets": clean_data.to_dict(orient="records")}, f)
