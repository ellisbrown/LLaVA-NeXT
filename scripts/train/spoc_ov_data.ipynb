# %%
import os
from tqdm import tqdm
import json
import pandas as pd
import yaml

from functools import lru_cache
import math

# %%
clean_path = "clean_ov_data.yaml"
with open(clean_path, 'r') as f:
    clean_ov_data = yaml.load(f, Loader=yaml.FullLoader)
clean_ov_df = pd.DataFrame(clean_ov_data["datasets"])
clean_ov_df["source"] = clean_ov_df["json_path"].str.replace("/data/weka/ellisb/datasets/video/", "").str.split("/").str[0]
clean_ov_df
# Out:
#                                             json_path  \
# 0   /data/weka/ellisb/datasets/video/llava_next/ll...
# 1   /data/weka/ellisb/datasets/video/llava_ov_data...
# 2   /data/weka/ellisb/datasets/video/llava_ov_data...
# 3   /data/weka/ellisb/datasets/video/llava_ov_data...
# 4   /data/weka/ellisb/datasets/video/llava_ov_data...
# ..                                                ...
# 65  /data/weka/ellisb/datasets/video/m4_instruct/m...
# 66  /data/weka/ellisb/datasets/video/llava_video_1...
# 67  /data/weka/ellisb/datasets/video/llava_video_1...
# 68  /data/weka/ellisb/datasets/video/llava_video_1...
# 69  /data/weka/ellisb/datasets/video/llava_video_1...
#
#                                       llava_json_path sampling_strategy  \
# 0   /mnt/bn/vl-research/data/llava_instruct/real_v...         first:50%
# 1   /mnt/bn/vl-research/data/llava_instruct/real_v...         first:10%
# 2   /mnt/bn/vl-research/data/llava_instruct/real_v...         first:10%
# 3   /mnt/bn/vl-research/data/llava_instruct/real_v...               all
# 4   /mnt/bn/vl-research/data/llava_instruct/real_v...               all
# ..                                                ...               ...
# 65  /mnt/bn/vl-research/data/llava_instruct/real_v...               all
# 66  /mnt/bn/vl-research/data/llava_instruct/real_v...               all
# 67  /mnt/bn/vl-research/data/llava_instruct/real_v...               all
# 68  /mnt/bn/vl-research/data/llava_instruct/real_v...               all
# 69  /mnt/bn/vl-research/data/llava_instruct/real_v...               all
#
#               source
# 0         llava_next
# 1      llava_ov_data
# 2      llava_ov_data
# 3      llava_ov_data
# 4      llava_ov_data
# ..               ...
# 65       m4_instruct
# 66  llava_video_178k
# 67  llava_video_178k
# 68  llava_video_178k
# 69  llava_video_178k
#
# [70 rows x 4 columns]

# %%
@lru_cache(maxsize=None)
def count_entries(file_path):
    """Count entries in a JSON or JSONL file."""
    try:
        if file_path.endswith('.json'):
            with open(file_path, 'r') as f:
                data = json.load(f)
                return len(data)
        elif file_path.endswith('.jsonl'):
            count = 0
            with open(file_path, 'r') as f:
                for _ in f:
                    count += 1
            return count
        else:
            raise ValueError(f"Unsupported file type: {file_path}")
    except Exception as e:
        print(f"Error counting entries in {file_path}: {e}")
        return 0

def calculate_sampled_count(sampling_strategy, total):
    """Calculate sampled count based on strategy."""
    if sampling_strategy == "all":
        return total

    strategy, value = sampling_strategy.split(":")

    if "%" in value:
        percentage = int(value.replace("%", ""))
        return math.ceil(total * percentage / 100)
    else:
        return min(int(value), total)

# %%
# Add progress bar for counting entries
tqdm.pandas(desc="Counting total samples")

# Calculate total samples
clean_ov_df['total_samples'] = clean_ov_df['json_path'].progress_apply(count_entries)
# Out:
# Counting total samples: 100%|██████████| 70/70 [01:09<00:00,  1.01it/s]

# %%
# Calculate sampled samples
clean_ov_df['sampled_samples'] = clean_ov_df.apply(
    lambda row: calculate_sampled_count(row['sampling_strategy'], row['total_samples']),
    axis=1
)

# %%
clean_ov_df
# Out:
#                                             json_path  \
# 0   /data/weka/ellisb/datasets/video/llava_next/ll...
# 1   /data/weka/ellisb/datasets/video/llava_ov_data...
# 2   /data/weka/ellisb/datasets/video/llava_ov_data...
# 3   /data/weka/ellisb/datasets/video/llava_ov_data...
# 4   /data/weka/ellisb/datasets/video/llava_ov_data...
# ..                                                ...
# 65  /data/weka/ellisb/datasets/video/m4_instruct/m...
# 66  /data/weka/ellisb/datasets/video/llava_video_1...
# 67  /data/weka/ellisb/datasets/video/llava_video_1...
# 68  /data/weka/ellisb/datasets/video/llava_video_1...
# 69  /data/weka/ellisb/datasets/video/llava_video_1...
#
#                                       llava_json_path sampling_strategy  \
# 0   /mnt/bn/vl-research/data/llava_instruct/real_v...         first:50%
# 1   /mnt/bn/vl-research/data/llava_instruct/real_v...         first:10%
# 2   /mnt/bn/vl-research/data/llava_instruct/real_v...         first:10%
# 3   /mnt/bn/vl-research/data/llava_instruct/real_v...               all
# 4   /mnt/bn/vl-research/data/llava_instruct/real_v...               all
# ..                                                ...               ...
# 65  /mnt/bn/vl-research/data/llava_instruct/real_v...               all
# 66  /mnt/bn/vl-research/data/llava_instruct/real_v...               all
# 67  /mnt/bn/vl-research/data/llava_instruct/real_v...               all
# 68  /mnt/bn/vl-research/data/llava_instruct/real_v...               all
# 69  /mnt/bn/vl-research/data/llava_instruct/real_v...               all
#
#               source  total_samples  sampled_samples
# 0         llava_next         738590           369295
# 1      llava_ov_data          87348             8735
# 2      llava_ov_data          99990             9999
# 3      llava_ov_data           4864             4864
# 4      llava_ov_data           4394             4394
# ..               ...            ...              ...
# 65       m4_instruct         615814           615814
# 66  llava_video_178k          48468            48468
# 67  llava_video_178k           5753             5753
# 68  llava_video_178k         255000           255000
# 69  llava_video_178k          48468            48468
#
# [70 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# Group by source and sum the total samples
source_total_samples = clean_ov_df.groupby('source')['total_samples'].sum()

# Calculate the percentage
total_samples_sum = source_total_samples.sum()
source_total_percentage = (source_total_samples / total_samples_sum) * 100

# Plot the breakdown
fig, ax1 = plt.subplots(figsize=(10, 6))

# Convert total samples to units of 1K
source_total_samples_k = source_total_samples / 1000

bars = ax1.bar(source_total_samples_k.index, source_total_samples_k, color='b')
ax1.set_xlabel('Source')
ax1.set_ylabel('Total Samples', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Add "k" to each left axis label
ax1.set_yticklabels([f'{int(tick)}k' for tick in ax1.get_yticks()])

# Create a secondary y-axis to plot the percentage
ax2 = ax1.twinx()
ax2.plot(source_total_samples_k.index, source_total_percentage, color='r', marker='o', alpha=0)
ax2.set_ylabel('Percentage (%)', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# Add labels to the top of the bars
for bar, num_samples, pct in zip(bars, source_total_samples, source_total_percentage):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width() / 2, height,
             f'{int(num_samples):,} ({pct:.1f}%)', ha='center', va='bottom')

plt.title('Breakdown of Total Samples by Source')
plt.show()
# Out:
# /tmp/ipykernel_775597/690284058.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([f'{int(tick)}k' for tick in ax1.get_yticks()])

# %%
# Group by source and sum the total samples
source_total_samples = clean_ov_df.groupby('source')['sampled_samples'].sum()

# Calculate the percentage
total_samples_sum = source_total_samples.sum()
source_total_percentage = (source_total_samples / total_samples_sum) * 100

# Plot the breakdown
fig, ax1 = plt.subplots(figsize=(10, 6))

# Convert total samples to units of 1K
source_total_samples_k = source_total_samples / 1000

bars = ax1.bar(source_total_samples_k.index, source_total_samples_k, color='b')
ax1.set_xlabel('Source')
ax1.set_ylabel('Total Samples', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Add "k" to each left axis label
ax1.set_yticklabels([f'{int(tick)}k' for tick in ax1.get_yticks()])

# Create a secondary y-axis to plot the percentage
ax2 = ax1.twinx()
ax2.plot(source_total_samples_k.index, source_total_percentage, color='r', marker='o', alpha=0)
ax2.set_ylabel('Percentage (%)', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# Add labels to the top of the bars
for bar, num_samples, pct in zip(bars, source_total_samples, source_total_percentage):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width() / 2, height,
             f'{int(num_samples):,} ({pct:.1f}%)', ha='center', va='bottom')

plt.title('Breakdown of Total Samples by Source')
plt.show()
# Out:
# /tmp/ipykernel_683805/3084690182.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([f'{int(tick)}k' for tick in ax1.get_yticks()])
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
total_samples = clean_ov_df['total_samples'].sum()
print(f"Total samples: {total_samples:,}")
# Out:
# Total samples: 4,238,966

# %%
def calculate_new_strategies(df, target_total):
    """
    Calculate new sampling strategies that maintain relative proportions
    while reducing total samples to target_total.

    Args:
        df: DataFrame with columns ['source', 'sampling_strategy', 'total_samples', 'sampled_samples']
        target_total: Desired total number of samples after resampling

    Returns:
        DataFrame with new_sampling_strategy and new_sampled_samples columns
    """
    # Calculate original proportions and total
    original_total = df['sampled_samples'].sum()
    df['proportion'] = df['sampled_samples'] / original_total

    # Calculate new allocations
    df['new_sampled_samples'] = (df['proportion'] * target_total).round().astype(int)

    def _create_new_strategy(row):
        strategy_type, strategy_val = row['sampling_strategy'].split(':') if ':' in row['sampling_strategy'] else (row['sampling_strategy'], None)

        # Calculate needed percentage/number
        needed = row['new_sampled_samples']
        total = row['total_samples']

        # Preserve original strategy type where possible
        if strategy_val and '%' in strategy_val:
            # Original was percentage based --> use absolute number
            return f"{strategy_type}:{needed}"
        elif strategy_val and strategy_val.isdigit():
            # Original was absolute number based
            return f"{strategy_type}:{needed}"
        else:
            # Handle 'all' strategy or other special cases
            if needed == total:
                return 'all'
            return f"random:{needed}"

    # Apply strategy conversion
    df['new_sampling_strategy'] = df.apply(_create_new_strategy, axis=1)

    return df

# Calculate original total samples
original_total = clean_ov_df['sampled_samples'].sum()

# Set target total (e.g., reduce by 50%)
target_total = 50_000

# Apply the function
result_df = calculate_new_strategies(clean_ov_df, target_total)

# Show results
print(result_df[['source', 'sampling_strategy', 'new_sampling_strategy',
                'sampled_samples', 'new_sampled_samples']])

# Verify new total
print(f"\nOriginal total: {original_total}")
print(f"New total: {result_df['new_sampled_samples'].sum()} (target: {target_total})")
# Out:
#               source sampling_strategy new_sampling_strategy  sampled_samples  \
# 0         llava_next         first:50%            first:9043           369295
# 1      llava_ov_data         first:10%             first:214             8735
# 2      llava_ov_data         first:10%             first:245             9999
# 3      llava_ov_data               all            random:119             4864
# 4      llava_ov_data               all            random:108             4394
# ..               ...               ...                   ...              ...
# 65       m4_instruct               all          random:15079           615814
# 66  llava_video_178k               all           random:1187            48468
# 67  llava_video_178k               all            random:141             5753
# 68  llava_video_178k               all           random:6244           255000
# 69  llava_video_178k               all           random:1187            48468
#
#     new_sampled_samples
# 0                  9043
# 1                   214
# 2                   245
# 3                   119
# 4                   108
# ..                  ...
# 65                15079
# 66                 1187
# 67                  141
# 68                 6244
# 69                 1187
#
# [70 rows x 5 columns]
#
# Original total: 2041895
# New total: 49998 (target: 50000)

# %%
# Group by source and sum the total samples
source_total_samples = result_df.groupby('source')['new_sampled_samples'].sum()

# Calculate the percentage
total_samples_sum = source_total_samples.sum()
source_total_percentage = (source_total_samples / total_samples_sum) * 100

# Plot the breakdown
fig, ax1 = plt.subplots(figsize=(10, 6))

# Convert total samples to units of 1K
source_total_samples_k = source_total_samples / 1000

bars = ax1.bar(source_total_samples_k.index, source_total_samples_k, color='b')
ax1.set_xlabel('Source')
ax1.set_ylabel('Total Samples', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Add "k" to each left axis label
ax1.set_yticklabels([f'{int(tick)}k' for tick in ax1.get_yticks()])

# Create a secondary y-axis to plot the percentage
ax2 = ax1.twinx()
ax2.plot(source_total_samples_k.index, source_total_percentage, color='r', marker='o', alpha=0)
ax2.set_ylabel('Percentage (%)', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# Add labels to the top of the bars
for bar, num_samples, pct in zip(bars, source_total_samples, source_total_percentage):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width() / 2, height,
             f'{int(num_samples):,} ({pct:.1f}%)', ha='center', va='bottom')

plt.title('Breakdown of Total Samples by Source')
plt.show()
# Out:
# /tmp/ipykernel_775597/1797951810.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([f'{int(tick)}k' for tick in ax1.get_yticks()])

# %%
def create_balanced_mix(original_df, new_entries_yaml, new_data_percentage):
    """
    Create a new data mix where new datasets make up specified percentage of total,
    while maintaining original proportions between existing sources.

    Args:
        original_df: Existing DataFrame with data sources
        new_entries_yaml: YAML string with new entries to add
        new_data_percentage: Percentage (0-100) that new data should occupy in final mix

    Returns:
        Tuple of (combined_df, original_adjusted_df, new_df)
    """
    # Process new entries
    new_data = yaml.safe_load(new_entries_yaml)['datasets']
    new_df = pd.DataFrame(new_data)

    # Add source column using same logic as original DF
    new_df["source"] = new_df["json_path"].str.split("/").str[-2]

    # Calculate samples for new data
    new_df['total_samples'] = new_df['json_path'].apply(count_entries)
    new_df['sampled_samples'] = new_df.apply(
        lambda row: calculate_sampled_count(row['sampling_strategy'], row['total_samples']),
        axis=1
    )

    # Calculate required scaling
    new_data_total = new_df['sampled_samples'].sum()
    target_new_data = new_data_total  # Start with full new data
    target_original_data = (target_new_data * (100 - new_data_percentage)) / new_data_percentage

    # Scale original data to match desired percentage
    original_total = original_df['sampled_samples'].sum()
    scale_factor = target_original_data / original_total

    # Apply scaling to original data
    original_adjusted_df = original_df.copy()
    original_adjusted_df['new_sampled_samples'] = (original_adjusted_df['sampled_samples'] * scale_factor).round().astype(int)

    # Create new sampling strategies for original data
    def update_strategy(row):
        # current = row['sampling_strategy']
        # if ':' in current:
        #     strategy, val = current.split(':')
        #     if '%' in val:
        #         # new_pct = float(val.strip('%')) * scale_factor
        #         # return f"{strategy}:{round(new_pct)}%"
        #         # use absolute number
        #         new_val = int(int(val.strip('%')))
        #         new_val = int()
        #     else:
        #         new_val = int(int(val) * scale_factor)
        #         return f"{strategy}:{new_val}"

        needed = row['new_sampled_samples']
        total = row['total_samples']

        # Preserve original strategy type where possible
        strategy, val = row['sampling_strategy'].split(':') if ':' in row['sampling_strategy'] else (row['sampling_strategy'], None)
        if val and '%' in val:
            # Original was percentage based --> use absolute number
            return f"{strategy}:{needed}"
        elif val and val.isdigit():
            # Original was absolute number based
            return f"{strategy}:{needed}"
        else:
            # Handle 'all' strategy or other special cases
            if needed == total:
                return 'all'
            return f"random:{needed}"

        return current

    original_adjusted_df['new_sampling_strategy'] = original_adjusted_df.apply(update_strategy, axis=1)

    # Combine datasets
    combined_df = pd.concat([
        original_adjusted_df[['source', 'json_path', 'new_sampling_strategy', 'new_sampled_samples']]
            .rename(columns={'new_sampling_strategy': 'sampling_strategy', 'new_sampled_samples': 'sampled_samples'}),
        new_df[['source', 'json_path', 'sampling_strategy', 'sampled_samples']]
    ], ignore_index=True)

    return combined_df, original_adjusted_df, new_df

# %% [markdown]
# ## Jan 17 data

# %%
new_entries_yaml = """
datasets:
  - json_path: /data/weka/ellisb/vida/experiment_output/dataset/jan17/combined_llava_ov_train_mc.jsonl
    llava_json_path: .nan
    sampling_strategy: random:100%
  - json_path: /data/weka/ellisb/vida/experiment_output/dataset/jan17/combined_llava_ov_train_oe.jsonl
    llava_json_path: .nan
    sampling_strategy: random:50%
"""

target_percentage = 80

# Create mix where new data makes up X% of total
combined_df, original_adjusted_df, new_df = create_balanced_mix(
    clean_ov_df,
    new_entries_yaml,
    new_data_percentage=target_percentage
)

# Show results
print("Combined Data Mix:")
print(combined_df[['source', 'sampling_strategy', 'sampled_samples']])
print("\nOriginal Data Adjusted:")
print(original_adjusted_df[['source', 'sampling_strategy', 'new_sampling_strategy', 'sampled_samples', 'new_sampled_samples']])
print("\nNew Data:")
print(new_df[['source', 'sampling_strategy', 'sampled_samples']])

# Verify percentages
total_samples = combined_df['sampled_samples'].sum()
new_data_percent = (new_df['sampled_samples'].sum() / total_samples) * 100
print(f"\nNew data makes up {new_data_percent:.1f}% of total {total_samples} samples")
# Out:
# Combined Data Mix:
#               source sampling_strategy  sampled_samples
# 0         llava_next        first:3395             3395
# 1      llava_ov_data          first:80               80
# 2      llava_ov_data          first:92               92
# 3      llava_ov_data         random:45               45
# 4      llava_ov_data         random:40               40
# ..               ...               ...              ...
# 67  llava_video_178k         random:53               53
# 68  llava_video_178k       random:2345             2345
# 69  llava_video_178k        random:446              446
# 70             jan17       random:100%            50064
# 71             jan17        random:50%            25032
#
# [72 rows x 3 columns]
#
# Original Data Adjusted:
#               source sampling_strategy new_sampling_strategy  sampled_samples  \
# 0         llava_next         first:50%            first:3395           369295
# 1      llava_ov_data         first:10%              first:80             8735
# 2      llava_ov_data         first:10%              first:92             9999
# 3      llava_ov_data               all             random:45             4864
# 4      llava_ov_data               all             random:40             4394
# ..               ...               ...                   ...              ...
# 65       m4_instruct               all           random:5662           615814
# 66  llava_video_178k               all            random:446            48468
# 67  llava_video_178k               all             random:53             5753
# 68  llava_video_178k               all           random:2345           255000
# 69  llava_video_178k               all            random:446            48468
#
#     new_sampled_samples
# 0                  3395
# 1                    80
# 2                    92
# 3                    45
# 4                    40
# ..                  ...
# 65                 5662
# 66                  446
# 67                   53
# 68                 2345
# 69                  446
#
# [70 rows x 5 columns]
#
# New Data:
#   source sampling_strategy  sampled_samples
# 0  jan17       random:100%            50064
# 1  jan17        random:50%            25032
#
# New data makes up 80.0% of total 93869 samples

# %%
# Group by source and sum the total samples
source_total_samples = combined_df.groupby('source')['sampled_samples'].sum()

# Calculate the percentage
total_samples_sum = source_total_samples.sum()
source_total_percentage = (source_total_samples / total_samples_sum) * 100

# Plot the breakdown
fig, ax1 = plt.subplots(figsize=(10, 6))

# Convert total samples to units of 1K
source_total_samples_k = source_total_samples / 1000

bars = ax1.bar(source_total_samples_k.index, source_total_samples_k, color='b')
ax1.set_xlabel('Source')
ax1.set_ylabel('Total Samples', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Add "k" to each left axis label
ax1.set_yticklabels([f'{int(tick)}k' for tick in ax1.get_yticks()])

# Create a secondary y-axis to plot the percentage
ax2 = ax1.twinx()
ax2.plot(source_total_samples_k.index, source_total_percentage, color='r', marker='o', alpha=0)
ax2.set_ylabel('Percentage (%)', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# Add labels to the top of the bars
for bar, num_samples, pct in zip(bars, source_total_samples, source_total_percentage):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width() / 2, height,
             f'{int(num_samples):,} ({pct:.1f}%)', ha='center', va='bottom')

plt.title('Breakdown of Total Samples by Source')
plt.show()
# Out:
# /tmp/ipykernel_775597/206838064.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([f'{int(tick)}k' for tick in ax1.get_yticks()])

# %%
import seaborn as sns

# Use a seaborn palette for a nicer look
# sns.set_palette("Set1")
sns.set_palette("tab20")

fig, ax = plt.subplots(figsize=(8, 8))
wedges, texts, autotexts = ax.pie(
    source_total_samples,
    labels=source_total_samples.index,
    autopct='%1.1f%%',
    startangle=90
)

for i, autotext in enumerate(autotexts):
    num_samples = source_total_samples.iloc[i]
    pct = source_total_percentage.iloc[i]
    autotext.set_text(f"$\\mathbf{{{pct:.1f}\\%}}$\n{num_samples:,}")

ax.axis('equal')
grand_total = source_total_samples.sum()
plt.title(rf"Source Distribution (Total Samples: $\mathbf{{{grand_total:,}}}$)")
plt.show()

# %%
# save the new data mix to a yaml file
ov_pct = 100 - target_percentage
combined_data_path = f"spoc_50k+ov_{ov_pct}pct.yaml"
with open(combined_data_path, 'w') as f:
    yaml.safe_dump({"datasets": combined_df.to_dict(orient='records')}, f)
print(f'Saved combined data mix to "./{combined_data_path}"')
# Out:
# Saved combined data mix to "./spoc_50k+ov_20pct.yaml"

# %% [markdown]
# ## Jan 7 Data

# %%
new_entries_yaml_jan7 = """
datasets:
  - json_path: /data/weka/ellisb/vida/experiment_output/dataset/jan7/combined_llava_ov_train_mc.jsonl
    llava_json_path: .nan
    sampling_strategy: random:100%
  - json_path: /data/weka/ellisb/vida/experiment_output/dataset/jan7/combined_llava_ov_train_oe.jsonl
    llava_json_path: .nan
    sampling_strategy: random:80%
"""

target_percentage = 60

# Create mix where new data makes up X% of total
combined_df_jan7, original_adjusted_df_jan7, new_df_jan7 = create_balanced_mix(
    clean_ov_df,
    new_entries_yaml_jan7,
    new_data_percentage=target_percentage
)

# Show results
print("Combined Data Mix:")
print(combined_df_jan7[['source', 'sampling_strategy', 'sampled_samples']])
print("\nOriginal Data Adjusted:")
print(original_adjusted_df_jan7[['source', 'sampling_strategy', 'new_sampling_strategy', 'sampled_samples', 'new_sampled_samples']])
print("\nNew Data:")
print(new_df_jan7[['source', 'sampling_strategy', 'sampled_samples']])

# Verify percentages
total_samples = combined_df_jan7['sampled_samples'].sum()
new_data_percent = (new_df_jan7['sampled_samples'].sum() / total_samples) * 100
print(f"\nNew data makes up {new_data_percent:.1f}% of total {total_samples} samples")
# Out:
# Combined Data Mix:
#               source sampling_strategy  sampled_samples
# 0         llava_next        first:1744             1744
# 1      llava_ov_data          first:41               41
# 2      llava_ov_data          first:47               47
# 3      llava_ov_data         random:23               23
# 4      llava_ov_data         random:21               21
# ..               ...               ...              ...
# 67  llava_video_178k         random:27               27
# 68  llava_video_178k       random:1204             1204
# 69  llava_video_178k        random:229              229
# 70              jan7       random:100%             8036
# 71              jan7        random:80%             6429
#
# [72 rows x 3 columns]
#
# Original Data Adjusted:
#               source sampling_strategy new_sampling_strategy  sampled_samples  \
# 0         llava_next         first:50%            first:1744           369295
# 1      llava_ov_data         first:10%              first:41             8735
# 2      llava_ov_data         first:10%              first:47             9999
# 3      llava_ov_data               all             random:23             4864
# 4      llava_ov_data               all             random:21             4394
# ..               ...               ...                   ...              ...
# 65       m4_instruct               all           random:2908           615814
# 66  llava_video_178k               all            random:229            48468
# 67  llava_video_178k               all             random:27             5753
# 68  llava_video_178k               all           random:1204           255000
# 69  llava_video_178k               all            random:229            48468
#
#     new_sampled_samples
# 0                  1744
# 1                    41
# 2                    47
# 3                    23
# 4                    21
# ..                  ...
# 65                 2908
# 66                  229
# 67                   27
# 68                 1204
# 69                  229
#
# [70 rows x 5 columns]
#
# New Data:
#   source sampling_strategy  sampled_samples
# 0   jan7       random:100%             8036
# 1   jan7        random:80%             6429
#
# New data makes up 60.0% of total 24103 samples

# %%
# Group by source and sum the total samples
source_total_samples = combined_df_jan7.groupby('source')['sampled_samples'].sum()

# Calculate the percentage
total_samples_sum = source_total_samples.sum()
source_total_percentage = (source_total_samples / total_samples_sum) * 100

# Plot the breakdown
fig, ax1 = plt.subplots(figsize=(10, 6))

# Convert total samples to units of 1K
source_total_samples_k = source_total_samples / 1000

bars = ax1.bar(source_total_samples_k.index, source_total_samples_k, color='b')
ax1.set_xlabel('Source')
ax1.set_ylabel('Total Samples', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Add "k" to each left axis label
ax1.set_yticklabels([f'{int(tick)}k' for tick in ax1.get_yticks()])

# Create a secondary y-axis to plot the percentage
ax2 = ax1.twinx()
ax2.plot(source_total_samples_k.index, source_total_percentage, color='r', marker='o', alpha=0)
ax2.set_ylabel('Percentage (%)', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# Add labels to the top of the bars
for bar, num_samples, pct in zip(bars, source_total_samples, source_total_percentage):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width() / 2, height,
             f'{int(num_samples):,} ({pct:.1f}%)', ha='center', va='bottom')

plt.title('Breakdown of Total Samples by Source')
plt.show()
# Out:
# /tmp/ipykernel_775597/1732833261.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_yticklabels([f'{int(tick)}k' for tick in ax1.get_yticks()])

# %%
import seaborn as sns

# Use a seaborn palette for a nicer look
# sns.set_palette("Set1")
sns.set_palette("tab20")

fig, ax = plt.subplots(figsize=(8, 8))
wedges, texts, autotexts = ax.pie(
    source_total_samples,
    labels=source_total_samples.index,
    autopct='%1.1f%%',
    startangle=90
)

for i, autotext in enumerate(autotexts):
    num_samples = source_total_samples.iloc[i]
    pct = source_total_percentage.iloc[i]
    autotext.set_text(f"$\\mathbf{{{pct:.1f}\\%}}$\n{num_samples:,}")

ax.axis('equal')
grand_total = source_total_samples.sum()
plt.title(rf"Source Distribution (Total Samples: $\mathbf{{{grand_total:,}}}$)")
plt.show()

# %%
# save the new data mix to a yaml file
ov_pct = 100 - target_percentage
combined_data_path = f"spoc_50k+ov_{ov_pct}pct.yaml"
with open(combined_data_path, 'w') as f:
    yaml.safe_dump({"datasets": combined_df.to_dict(orient='records')}, f)
print(f'Saved combined data mix to "./{combined_data_path}"')
# Out:
# Saved combined data mix to "./spoc_8k+ov_40pct.yaml"
